# %% [markdown]
# # Web Scraping with  Beautiful Soup
# ![The words Beautiful Soup stylized](https://imgur.com/Zf7atCZ.jpg)
# <a href="https://bestprogrammer.ru/izuchenie/veb-skraping-s-pomoshhyu-beautiful-soup">Image Source</a>

# %%
# Import libaries
import requests
from bs4 import BeautifulSoup

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ### Step 1: Creating a soup object from the home page

# %%
url = "https://pages.git.generalassemb.ly/rldaggie/for-scraping/"

req = requests.get(url)

req.status_code
# Out:
# 200

# %% [markdown]
# ### Step 2: Scraping the home page soup for every restaurant
#
# For this, we're going to create a list of dictionaries, one for each restaurant.
#
# Each dictionary will contain the restaurant's name and path from the `href`.

# %%
soup = BeautifulSoup(req.text, "lxml")

# %%
results_list = []

all_td = soup.find_all('td')

for element in all_td:
    
    # start a dictionary to store this item's data
    result = {}
    
    # get the title and full link/url
    a_href = element.find('a')
    
    if a_href is not None:
        result['name'] = a_href.text
        result['href'] = a_href['href']
    #saving these in the results dictionary, key = link, result = title    
        
    if len(result) == 2:
        results_list.append(result)

# %%
results_list
# Out:
# [{'name': 'A&W Restaurants', 'href': 'restaurants/1.html'},
#  {'name': "Applebee's",
#   'href': 'restaurants/2.html',
#   'foods': [{'name': 'Original Bacon Double Cheeseburger',
#     'category': 'Original Bacon Double Cheeseburger',
#     'calories': 'Original Bacon Double Cheeseburger',
#     'fat': 'Original Bacon Double Cheeseburger',
#     'carbs': 'Original Bacon Double Cheeseburger',
#     'restaurant': "Applebee's"},
#    {'name': 'Coney (Chili) Dog',
#     'category': 'Coney (Chili) Dog',
#     'calories': 'Coney (Chili) Dog',
#     'fat': 'Coney (Chili) Dog',
#     'carbs': 'Coney (Chili) Dog',
#     'restaurant': "Arby's"},
#    {'name': 'Chili Fries',
#     'category': 'Chili Fries',
#     'calories': 'Chili Fries',
#     'fat': 'Chili Fries',
#     'carbs': 'Chili Fries',
#     'restaurant': 'Atlanta Bread Company'},
#    {'name': 'Strawberry Milkshake (small)',
#     'category': 'Strawberry Milkshake (small)',
#     'calories': 'Strawberry Milkshake (small)',
#     'fat': 'Strawberry Milkshake (small)',
#     'carbs': 'Strawberry Milkshake (small)',
#     'restaurant': "Bojangle's Famous Chicken 'n Biscuits"},
#    {'name': 'A&amp;W® Root Beer Freeze (large)',
#     'category': 'A&amp;W® Root Beer Freeze (large)',
#     'calories': 'A&amp;W® Root Beer Freeze (large)',
#     'fat': 'A&amp;W® Root Beer Freeze (large)',
#     'carbs': 'A&amp;W® Root Beer Freeze (large)',
#     'restaurant': 'Buffalo Wild Wings'},
#    {'name': 'Caramel Sundae',
#     'category': 'Caramel Sundae',
#     'calories': 'Caramel Sundae',
#     'fat': 'Caramel Sundae',
#     'carbs': 'Caramel Sundae',
#     'restaurant': 'Burger King'},
#    {'name': 'Strawberry Banana Smoothee',
#     'category': 'Strawberry Banana Smoothee',
#     'calories': 'Strawberry Banana Smoothee',
#     'fat': 'Strawberry Banana Smoothee',
#     'carbs': 'Strawberry Banana Smoothee',
#     'restaurant': "Captain D's"},
#    {'name': 'Chocolate Fudge Blendrrr',
#     'category': 'Chocolate Fudge Blendrrr',
#     'calories': 'Chocolate Fudge Blendrrr',
#     'fat': 'Chocolate Fudge Blendrrr',
#     'carbs': 'Chocolate Fudge Blendrrr',
#     'restaurant': "Carl's Jr."},
#    {'name': 'Strawberry Limeade',
#     'category': 'Strawberry Limeade',
#     'calories': 'Strawberry Limeade',
#     'fat': 'Strawberry Limeade',
#     'carbs': 'Strawberry Limeade',
#     'restaurant': "Charley's Grilled Subs"},
#    {'name': 'Watermelon Slushee',
#     'category': 'Watermelon Slushee',
#     'calories': 'Watermelon Slushee',
#     'fat': 'Watermelon Slushee',
#     'carbs': 'Watermelon Slushee',
#     'restaurant': 'Chick-fil-A'},
#    {'name': 'Lime Slushee',
#     'category': 'Lime Slushee',
#     'calories': 'Lime Slushee',
#     'fat': 'Lime Slushee',
#     'carbs': 'Lime Slushee',
#     'restaurant': "Chili's"},
#    {'name': 'A&amp;W® Root Beer',
#     'category': 'A&amp;W® Root Beer',
#     'calories': 'A&amp;W® Root Beer',
#     'fat': 'A&amp;W® Root Beer',
#     'carbs': 'A&amp;W® Root Beer',
#     'restaurant': 'Chipotle Mexican Grill'},
#    {'name': 'Cheeseburger',
#     'category': 'Cheeseburger',
#     'calories': 'Cheeseburger',
#     'fat': 'Cheeseburger',
#     'carbs': 'Cheeseburger',
#     'restaurant': "Church's"},
#    {'name': 'French Fries (Regular)',
#     'category': 'French Fries (Regular)',
#     'calories': 'French Fries (Regular)',
#     'fat': 'French Fries (Regular)',
#     'carbs': 'French Fries (Regular)',
#     'restaurant': 'Corner Bakery Cafe'},
#    {'name': 'Cheese Curds (Large)',
#     'category': 'Cheese Curds (Large)',
#     'calories': 'Cheese Curds (Large)',
#     'fat': 'Cheese Curds (Large)',
#     'carbs': 'Cheese Curds (Large)',
#     'restaurant': 'Dairy Queen'},
#    {'name': 'Chocolate Milkshake (small)',
#     'category': 'Chocolate Milkshake (small)',
#     'calories': 'Chocolate Milkshake (small)',
#     'fat': 'Chocolate Milkshake (small)',
#     'carbs': 'Chocolate Milkshake (small)',
#     'restaurant': "Denny's"},
#    {'name': 'Orange Freeze (small)',
#     'category': 'Orange Freeze (small)',
#     'calories': 'Orange Freeze (small)',
#     'fat': 'Orange Freeze (small)',
#     'carbs': 'Orange Freeze (small)',
#     'restaurant': 'El Pollo Loco'},
#    {'name': 'A&amp;W® Diet Root Beer Float (small)',
#     'category': 'A&amp;W® Diet Root Beer Float (small)',
#     'calories': 'A&amp;W® Diet Root Beer Float (small)',
#     'fat': 'A&amp;W® Diet Root Beer Float (small)',
#     'carbs': 'A&amp;W® Diet Root Beer Float (small)',
#     'restaurant': 'FATZ'},
#    {'name': 'Strawberry Smoothee',
#     'category': 'Strawberry Smoothee',
#     'calories': 'Strawberry Smoothee',
#     'fat': 'Strawberry Smoothee',
#     'carbs': 'Strawberry Smoothee',
#     'restaurant': "Fazoli's"},
#    {'name': 'Limeade',
#     'category': 'Limeade',
#     'calories': 'Limeade',
#     'fat': 'Limeade',
#     'carbs': 'Limeade',
#     'restaurant': 'Five Guys Burgers and Fries'},
#    {'name': 'Cherry Limeade',
#     'category': 'Cherry Limeade',
#     'calories': 'Cherry Limeade',
#     'fat': 'Cherry Limeade',
#     'carbs': 'Cherry Limeade',
#     'restaurant': 'Golden Chick'},
#    {'name': 'Lemon Slushee',
#     'category': 'Lemon Slushee',
#     'calories': 'Lemon Slushee',
#     'fat': 'Lemon Slushee',
#     'carbs': 'Lemon Slushee',
#     'restaurant': "Hardee's"},
#    {'name': 'Blue Raspberry Slushee',
#     'category': 'Blue Raspberry Slushee',
#     'calories': 'Blue Raspberry Slushee',
#     'fat': 'Blue Raspberry Slushee',
#     'carbs': 'Blue Raspberry Slushee',
#     'restaurant': 'IHOP'},
#    {'name': 'A&amp;W® Diet Root Beer',
#     'category': 'A&amp;W® Diet Root Beer',
#     'calories': 'A&amp;W® Diet Root Beer',
#     'fat': 'A&amp;W® Diet Root Beer',
#     'carbs': 'A&amp;W® Diet Root Beer',
#     'restaurant': 'In-N-Out Burger'},
#    {'name': 'Grilled Chicken Sandwich',
#     'category': 'Grilled Chicken Sandwich',
#     'calories': 'Grilled Chicken Sandwich',
#     'fat': 'Grilled Chicken Sandwich',
#     'carbs': 'Grilled Chicken Sandwich',
#     'restaurant': 'Jack in the Box'},
#    {'name': 'French Fries (Large)',
#     'category': 'French Fries (Large)',
#     'calories': 'French Fries (Large)',
#     'fat': 'French Fries (Large)',
#     'carbs': 'French Fries (Large)',
#     'restaurant': 'Jimmy Johns'},
#    {'name': 'Chili',
#     'category': 'Chili',
#     'calories': 'Chili',
#     'fat': 'Chili',
#     'carbs': 'Chili',
#     'restaurant': "Joe's Crab Shack"},
#    {'name': 'Chocolate Milkshake (medium)',
#     'category': 'Chocolate Milkshake (medium)',
#     'calories': 'Chocolate Milkshake (medium)',
#     'fat': 'Chocolate Milkshake (medium)',
#     'carbs': 'Chocolate Milkshake (medium)',
#     'restaurant': 'KFC'},
#    {'name': 'Orange Freeze (medium)',
#     'category': 'Orange Freeze (medium)',
#     'calories': 'Orange Freeze (medium)',
#     'fat': 'Orange Freeze (medium)',
#     'carbs': 'Orange Freeze (medium)',
#     'restaurant': "McDonald's"},
#    {'name': 'A&amp;W® Diet Root Beer Float (medium)',
#     'category': 'A&amp;W® Diet Root Beer Float (medium)',
#     'calories': 'A&amp;W® Diet Root Beer Float (medium)',
#     'fat': 'A&amp;W® Diet Root Beer Float (medium)',
#     'carbs': 'A&amp;W® Diet Root Beer Float (medium)',
#     'restaurant': "O'Charley's"},
#    {'name': 'Orange Float (large)',
#     'category': 'Orange Float (large)',
#     'calories': 'Orange Float (large)',
#     'fat': 'Orange Float (large)',
#     'carbs': 'Orange Float (large)',
#     'restaurant': 'Olive Garden'},
#    {'name': "Reese's® Peanut Butter Fudge Blendrrr",
#     'category': "Reese's® Peanut Butter Fudge Blendrrr",
#     'calories': "Reese's® Peanut Butter Fudge Blendrrr",
#     'fat': "Reese's® Peanut Butter Fudge Blendrrr",
#     'carbs': "Reese's® Peanut Butter Fudge Blendrrr",
#     'restaurant': 'Outback Steakhouse'},
#    {'name': 'Limeade',
#     'category': 'Limeade',
#     'calories': 'Limeade',
#     'fat': 'Limeade',
#     'carbs': 'Limeade',
#     'restaurant': 'Panda Express'},
#    {'name': 'Cherry Limeade',
#     'category': 'Cherry Limeade',
#     'calories': 'Cherry Limeade',
#     'fat': 'Cherry Limeade',
#     'carbs': 'Cherry Limeade',
#     'restaurant': 'Panera Bread'},
#    {'name': 'Lemon Slushee',
#     'category': 'Lemon Slushee',
#     'calories': 'Lemon Slushee',
#     'fat': 'Lemon Slushee',
#     'carbs': 'Lemon Slushee',
#     'restaurant': "Popeye's"},
#    {'name': 'Blue Raspberry Slushee',
#     'category': 'Blue Raspberry Slushee',
#     'calories': 'Blue Raspberry Slushee',
#     'fat': 'Blue Raspberry Slushee',
#     'carbs': 'Blue Raspberry Slushee',
#     'restaurant': 'Quiznos'},
#    {'name': 'A&amp;W® Diet Root Beer',
#     'category': 'A&amp;W® Diet Root Beer',
#     'calories': 'A&amp;W® Diet Root Beer',
#     'fat': 'A&amp;W® Diet Root Beer',
#     'carbs': 'A&amp;W® Diet Root Beer',
#     'restaurant': 'Red Robin Gourmet Burgers'},
#    {'name': 'Original Double Cheeseburger',
#     'category': 'Original Double Cheeseburger',
#     'calories': 'Original Double Cheeseburger',
#     'fat': 'Original Double Cheeseburger',
#     'carbs': 'Original Double Cheeseburger',
#     'restaurant': "Romano's Macaroni Grill"},
#    {'name': 'Coney (Chili) Cheese Dog',
#     'category': 'Coney (Chili) Cheese Dog',
#     'calories': 'Coney (Chili) Cheese Dog',
#     'fat': 'Coney (Chili) Cheese Dog',
#     'carbs': 'Coney (Chili) Cheese Dog',
#     'restaurant': 'Ruby Tuesday'},
#    {'name': 'Breaded Onion Rings (Regular)',
#     'category': 'Breaded Onion Rings (Regular)',
#     'calories': 'Breaded Onion Rings (Regular)',
#     'fat': 'Breaded Onion Rings (Regular)',
#     'carbs': 'Breaded Onion Rings (Regular)',
#     'restaurant': 'Subway'},
#    {'name': 'Strawberry Milkshake (medium)',
#     'category': 'Strawberry Milkshake (medium)',
#     'calories': 'Strawberry Milkshake (medium)',
#     'fat': 'Strawberry Milkshake (medium)',
#     'carbs': 'Strawberry Milkshake (medium)',
#     'restaurant': 'Taco Bell'},
#    {'name': 'A&amp;W® Diet Root Beer Freeze (small)',
#     'category': 'A&amp;W® Diet Root Beer Freeze (small)',
#     'calories': 'A&amp;W® Diet Root Beer Freeze (small)',
#     'fat': 'A&amp;W® Diet Root Beer Freeze (small)',
#     'carbs': 'A&amp;W® Diet Root Beer Freeze (small)',
#     'restaurant': 'Taco Bueno'},
#    {'name': 'A&amp;W® Root Beer Float (small)',
#     'category': 'A&amp;W® Root Beer Float (small)',
#     'calories': 'A&amp;W® Root Beer Float (small)',
#     'fat': 'A&amp;W® Root Beer Float (small)',
#     'carbs': 'A&amp;W® Root Beer Float (small)',
#     'restaurant': "Wendy's"}]},
#  {'name': "Arby's",
#   'href': 'restaurants/3.html',
#   'foods': [{'name': 'Original Bacon Double Cheeseburger',
#     'category': 'Original Bacon Double Cheeseburger',
#     'calories': 'Original Bacon Double Cheeseburger',
#     'fat': 'Original Bacon Double Cheeseburger',
#     'carbs': 'Original Bacon Double Cheeseburger',
#     'restaurant': "Applebee's"},
#    {'name': 'Coney (Chili) Dog',
#     'category': 'Coney (Chili) Dog',
#     'calories': 'Coney (Chili) Dog',
#     'fat': 'Coney (Chili) Dog',
#     'carbs': 'Coney (Chili) Dog',
#     'restaurant': "Arby's"},
#    {'name': 'Chili Fries',
#     'category': 'Chili Fries',
#     'calories': 'Chili Fries',
#     'fat': 'Chili Fries',
#     'carbs': 'Chili Fries',
#     'restaurant': 'Atlanta Bread Company'},
#    {'name': 'Strawberry Milkshake (small)',
#     'category': 'Strawberry Milkshake (small)',
#     'calories': 'Strawberry Milkshake (small)',
#     'fat': 'Strawberry Milkshake (small)',
#     'carbs': 'Strawberry Milkshake (small)',
#     'restaurant': "Bojangle's Famous Chicken 'n Biscuits"},
#    {'name': 'A&amp;W® Root Beer Freeze (large)',
#     'category': 'A&amp;W® Root Beer Freeze (large)',
#     'calories': 'A&amp;W® Root Beer Freeze (large)',
#     'fat': 'A&amp;W® Root Beer Freeze (large)',
#     'carbs': 'A&amp;W® Root Beer Freeze (large)',
#     'restaurant': 'Buffalo Wild Wings'},
#    {'name': 'Caramel Sundae',
#     'category': 'Caramel Sundae',
#     'calories': 'Caramel Sundae',
#     'fat': 'Caramel Sundae',
#     'carbs': 'Caramel Sundae',
#     'restaurant': 'Burger King'},
#    {'name': 'Strawberry Banana Smoothee',
#     'category': 'Strawberry Banana Smoothee',
#     'calories': 'Strawberry Banana Smoothee',
#     'fat': 'Strawberry Banana Smoothee',
#     'carbs': 'Strawberry Banana Smoothee',
#     'restaurant': "Captain D's"},
#    {'name': 'Chocolate Fudge Blendrrr',
#     'category': 'Chocolate Fudge Blendrrr',
#     'calories': 'Chocolate Fudge Blendrrr',
#     'fat': 'Chocolate Fudge Blendrrr',
#     'carbs': 'Chocolate Fudge Blendrrr',
#     'restaurant': "Carl's Jr."},
#    {'name': 'Strawberry Limeade',
#     'category': 'Strawberry Limeade',
#     'calories': 'Strawberry Limeade',
#     'fat': 'Strawberry Limeade',
#     'carbs': 'Strawberry Limeade',
#     'restaurant': "Charley's Grilled Subs"},
#    {'name': 'Watermelon Slushee',
#     'category': 'Watermelon Slushee',
#     'calories': 'Watermelon Slushee',
#     'fat': 'Watermelon Slushee',
#     'carbs': 'Watermelon Slushee',
#     'restaurant': 'Chick-fil-A'},
#    {'name': 'Lime Slushee',
#     'category': 'Lime Slushee',
#     'calories': 'Lime Slushee',
#     'fat': 'Lime Slushee',
#     'carbs': 'Lime Slushee',
#     'restaurant': "Chili's"},
#    {'name': 'A&amp;W® Root Beer',
#     'category': 'A&amp;W® Root Beer',
#     'calories': 'A&amp;W® Root Beer',
#     'fat': 'A&amp;W® Root Beer',
#     'carbs': 'A&amp;W® Root Beer',
#     'restaurant': 'Chipotle Mexican Grill'},
#    {'name': 'Cheeseburger',
#     'category': 'Cheeseburger',
#     'calories': 'Cheeseburger',
#     'fat': 'Cheeseburger',
#     'carbs': 'Cheeseburger',
#     'restaurant': "Church's"},
#    {'name': 'French Fries (Regular)',
#     'category': 'French Fries (Regular)',
#     'calories': 'French Fries (Regular)',
#     'fat': 'French Fries (Regular)',
#     'carbs': 'French Fries (Regular)',
#     'restaurant': 'Corner Bakery Cafe'},
#    {'name': 'Cheese Curds (Large)',
#     'category': 'Cheese Curds (Large)',
#     'calories': 'Cheese Curds (Large)',
#     'fat': 'Cheese Curds (Large)',
#     'carbs': 'Cheese Curds (Large)',
#     'restaurant': 'Dairy Queen'},
#    {'name': 'Chocolate Milkshake (small)',
#     'category': 'Chocolate Milkshake (small)',
#     'calories': 'Chocolate Milkshake (small)',
#     'fat': 'Chocolate Milkshake (small)',
#     'carbs': 'Chocolate Milkshake (small)',
#     'restaurant': "Denny's"},
#    {'name': 'Orange Freeze (small)',
#     'category': 'Orange Freeze (small)',
#     'calories': 'Orange Freeze (small)',
#     'fat': 'Orange Freeze (small)',
#     'carbs': 'Orange Freeze (small)',
#     'restaurant': 'El Pollo Loco'},
#    {'name': 'A&amp;W® Diet Root Beer Float (small)',
#     'category': 'A&amp;W® Diet Root Beer Float (small)',
#     'calories': 'A&amp;W® Diet Root Beer Float (small)',
#     'fat': 'A&amp;W® Diet Root Beer Float (small)',
#     'carbs': 'A&amp;W® Diet Root Beer Float (small)',
#     'restaurant': 'FATZ'},
#    {'name': 'Strawberry Smoothee',
#     'category': 'Strawberry Smoothee',
#     'calories': 'Strawberry Smoothee',
#     'fat': 'Strawberry Smoothee',
#     'carbs': 'Strawberry Smoothee',
#     'restaurant': "Fazoli's"},
#    {'name': 'Limeade',
#     'category': 'Limeade',
#     'calories': 'Limeade',
#     'fat': 'Limeade',
#     'carbs': 'Limeade',
#     'restaurant': 'Five Guys Burgers and Fries'},
#    {'name': 'Cherry Limeade',
#     'category': 'Cherry Limeade',
#     'calories': 'Cherry Limeade',
#     'fat': 'Cherry Limeade',
#     'carbs': 'Cherry Limeade',
#     'restaurant': 'Golden Chick'},
#    {'name': 'Lemon Slushee',
#     'category': 'Lemon Slushee',
#     'calories': 'Lemon Slushee',
#     'fat': 'Lemon Slushee',
#     'carbs': 'Lemon Slushee',
#     'restaurant': "Hardee's"},
#    {'name': 'Blue Raspberry Slushee',
#     'category': 'Blue Raspberry Slushee',
#     'calories': 'Blue Raspberry Slushee',
#     'fat': 'Blue Raspberry Slushee',
#     'carbs': 'Blue Raspberry Slushee',
#     'restaurant': 'IHOP'},
#    {'name': 'A&amp;W® Diet Root Beer',
#     'category': 'A&amp;W® Diet Root Beer',
#     'calories': 'A&amp;W® Diet Root Beer',
#     'fat': 'A&amp;W® Diet Root Beer',
#     'carbs': 'A&amp;W® Diet Root Beer',
#     'restaurant': 'In-N-Out Burger'},
#    {'name': 'Grilled Chicken Sandwich',
#     'category': 'Grilled Chicken Sandwich',
#     'calories': 'Grilled Chicken Sandwich',
#     'fat': 'Grilled Chicken Sandwich',
#     'carbs': 'Grilled Chicken Sandwich',
#     'restaurant': 'Jack in the Box'},
#    {'name': 'French Fries (Large)',
#     'category': 'French Fries (Large)',
#     'calories': 'French Fries (Large)',
#     'fat': 'French Fries (Large)',
#     'carbs': 'French Fries (Large)',
#     'restaurant': 'Jimmy Johns'},
#    {'name': 'Chili',
#     'category': 'Chili',
#     'calories': 'Chili',
#     'fat': 'Chili',
#     'carbs': 'Chili',
#     'restaurant': "Joe's Crab Shack"},
#    {'name': 'Chocolate Milkshake (medium)',
#     'category': 'Chocolate Milkshake (medium)',
#     'calories': 'Chocolate Milkshake (medium)',
#     'fat': 'Chocolate Milkshake (medium)',
#     'carbs': 'Chocolate Milkshake (medium)',
#     'restaurant': 'KFC'},
#    {'name': 'Orange Freeze (medium)',
#     'category': 'Orange Freeze (medium)',
#     'calories': 'Orange Freeze (medium)',
#     'fat': 'Orange Freeze (medium)',
#     'carbs': 'Orange Freeze (medium)',
#     'restaurant': "McDonald's"},
#    {'name': 'A&amp;W® Diet Root Beer Float (medium)',
#     'category': 'A&amp;W® Diet Root Beer Float (medium)',
#     'calories': 'A&amp;W® Diet Root Beer Float (medium)',
#     'fat': 'A&amp;W® Diet Root Beer Float (medium)',
#     'carbs': 'A&amp;W® Diet Root Beer Float (medium)',
#     'restaurant': "O'Charley's"},
#    {'name': 'Orange Float (large)',
#     'category': 'Orange Float (large)',
#     'calories': 'Orange Float (large)',
#     'fat': 'Orange Float (large)',
#     'carbs': 'Orange Float (large)',
#     'restaurant': 'Olive Garden'},
#    {'name': "Reese's® Peanut Butter Fudge Blendrrr",
#     'category': "Reese's® Peanut Butter Fudge Blendrrr",
#     'calories': "Reese's® Peanut Butter Fudge Blendrrr",
#     'fat': "Reese's® Peanut Butter Fudge Blendrrr",
#     'carbs': "Reese's® Peanut Butter Fudge Blendrrr",
#     'restaurant': 'Outback Steakhouse'},
#    {'name': 'Limeade',
#     'category': 'Limeade',
#     'calories': 'Limeade',
#     'fat': 'Limeade',
#     'carbs': 'Limeade',
#     'restaurant': 'Panda Express'},
#    {'name': 'Cherry Limeade',
#     'category': 'Cherry Limeade',
#     'calories': 'Cherry Limeade',
#     'fat': 'Cherry Limeade',
#     'carbs': 'Cherry Limeade',
#     'restaurant': 'Panera Bread'},
#    {'name': 'Lemon Slushee',
#     'category': 'Lemon Slushee',
#     'calories': 'Lemon Slushee',
#     'fat': 'Lemon Slushee',
#     'carbs': 'Lemon Slushee',
#     'restaurant': "Popeye's"},
#    {'name': 'Blue Raspberry Slushee',
#     'category': 'Blue Raspberry Slushee',
#     'calories': 'Blue Raspberry Slushee',
#     'fat': 'Blue Raspberry Slushee',
#     'carbs': 'Blue Raspberry Slushee',
#     'restaurant': 'Quiznos'},
#    {'name': 'A&amp;W® Diet Root Beer',
#     'category': 'A&amp;W® Diet Root Beer',
#     'calories': 'A&amp;W® Diet Root Beer',
#     'fat': 'A&amp;W® Diet Root Beer',
#     'carbs': 'A&amp;W® Diet Root Beer',
#     'restaurant': 'Red Robin Gourmet Burgers'},
#    {'name': 'Original Double Cheeseburger',
#     'category': 'Original Double Cheeseburger',
#     'calories': 'Original Double Cheeseburger',
#     'fat': 'Original Double Cheeseburger',
#     'carbs': 'Original Double Cheeseburger',
#     'restaurant': "Romano's Macaroni Grill"},
#    {'name': 'Coney (Chili) Cheese Dog',
#     'category': 'Coney (Chili) Cheese Dog',
#     'calories': 'Coney (Chili) Cheese Dog',
#     'fat': 'Coney (Chili) Cheese Dog',
#     'carbs': 'Coney (Chili) Cheese Dog',
#     'restaurant': 'Ruby Tuesday'},
#    {'name': 'Breaded Onion Rings (Regular)',
#     'category': 'Breaded Onion Rings (Regular)',
#     'calories': 'Breaded Onion Rings (Regular)',
#     'fat': 'Breaded Onion Rings (Regular)',
#     'carbs': 'Breaded Onion Rings (Regular)',
#     'restaurant': 'Subway'},
#    {'name': 'Strawberry Milkshake (medium)',
#     'category': 'Strawberry Milkshake (medium)',
#     'calories': 'Strawberry Milkshake (medium)',
#     'fat': 'Strawberry Milkshake (medium)',
#     'carbs': 'Strawberry Milkshake (medium)',
#     'restaurant': 'Taco Bell'},
#    {'name': 'A&amp;W® Diet Root Beer Freeze (small)',
#     'category': 'A&amp;W® Diet Root Beer Freeze (small)',
#     'calories': 'A&amp;W® Diet Root Beer Freeze (small)',
#     'fat': 'A&amp;W® Diet Root Beer Freeze (small)',
#     'carbs': 'A&amp;W® Diet Root Beer Freeze (small)',
#     'restaurant': 'Taco Bueno'},
#    {'name': 'A&amp;W® Root Beer Float (small)',
#     'category': 'A&amp;W® Root Beer Float (small)',
#     'calories': 'A&amp;W® Root Beer Float (small)',
#     'fat': 'A&amp;W® Root Beer Float (small)',
#     'carbs': 'A&amp;W® Root Beer Float (small)',
#     'restaurant': "Wendy's"}]},
#  {'name': 'Atlanta Bread Company',
#   'href': 'restaurants/4.html',
#   'foods': [{'name': 'Original Bacon Double Cheeseburger',
#     'category': 'Original Bacon Double Cheeseburger',
#     'calories': 'Original Bacon Double Cheeseburger',
#     'fat': 'Original Bacon Double Cheeseburger',
#     'carbs': 'Original Bacon Double Cheeseburger',
#     'restaurant': "Applebee's"},
#    {'name': 'Coney (Chili) Dog',
#     'category': 'Coney (Chili) Dog',
#     'calories': 'Coney (Chili) Dog',
#     'fat': 'Coney (Chili) Dog',
#     'carbs': 'Coney (Chili) Dog',
#     'restaurant': "Arby's"},
#    {'name': 'Chili Fries',
#     'category': 'Chili Fries',
#     'calories': 'Chili Fries',
#     'fat': 'Chili Fries',
#     'carbs': 'Chili Fries',
#     'restaurant': 'Atlanta Bread Company'},
#    {'name': 'Strawberry Milkshake (small)',
#     'category': 'Strawberry Milkshake (small)',
#     'calories': 'Strawberry Milkshake (small)',
#     'fat': 'Strawberry Milkshake (small)',
#     'carbs': 'Strawberry Milkshake (small)',
#     'restaurant': "Bojangle's Famous Chicken 'n Biscuits"},
#    {'name': 'A&amp;W® Root Beer Freeze (large)',
#     'category': 'A&amp;W® Root Beer Freeze (large)',
#     'calories': 'A&amp;W® Root Beer Freeze (large)',
#     'fat': 'A&amp;W® Root Beer Freeze (large)',
#     'carbs': 'A&amp;W® Root Beer Freeze (large)',
#     'restaurant': 'Buffalo Wild Wings'},
#    {'name': 'Caramel Sundae',
#     'category': 'Caramel Sundae',
#     'calories': 'Caramel Sundae',
#     'fat': 'Caramel Sundae',
#     'carbs': 'Caramel Sundae',
#     'restaurant': 'Burger King'},
#    {'name': 'Strawberry Banana Smoothee',
#     'category': 'Strawberry Banana Smoothee',
#     'calories': 'Strawberry Banana Smoothee',
#     'fat': 'Strawberry Banana Smoothee',
#     'carbs': 'Strawberry Banana Smoothee',
#     'restaurant': "Captain D's"},
#    {'name': 'Chocolate Fudge Blendrrr',
#     'category': 'Chocolate Fudge Blendrrr',
#     'calories': 'Chocolate Fudge Blendrrr',
#     'fat': 'Chocolate Fudge Blendrrr',
#     'carbs': 'Chocolate Fudge Blendrrr',
#     'restaurant': "Carl's Jr."},
#    {'name': 'Strawberry Limeade',
#     'category': 'Strawberry Limeade',
#     'calories': 'Strawberry Limeade',
#     'fat': 'Strawberry Limeade',
#     'carbs': 'Strawberry Limeade',
#     'restaurant': "Charley's Grilled Subs"},
#    {'name': 'Watermelon Slushee',
#     'category': 'Watermelon Slushee',
#     'calories': 'Watermelon Slushee',
#     'fat': 'Watermelon Slushee',
#     'carbs': 'Watermelon Slushee',
#     'restaurant': 'Chick-fil-A'},
#    {'name': 'Lime Slushee',
#     'category': 'Lime Slushee',
#     'calories': 'Lime Slushee',
#     'fat': 'Lime Slushee',
#     'carbs': 'Lime Slushee',
#     'restaurant': "Chili's"},
#    {'name': 'A&amp;W® Root Beer',
#     'category': 'A&amp;W® Root Beer',
#     'calories': 'A&amp;W® Root Beer',
#     'fat': 'A&amp;W® Root Beer',
#     'carbs': 'A&amp;W® Root Beer',
#     'restaurant': 'Chipotle Mexican Grill'},
#    {'name': 'Cheeseburger',
#     'category': 'Cheeseburger',
#     'calories': 'Cheeseburger',
#     'fat': 'Cheeseburger',
#     'carbs': 'Cheeseburger',
#     'restaurant': "Church's"},
#    {'name': 'French Fries (Regular)',
#     'category': 'French Fries (Regular)',
#     'calories': 'French Fries (Regular)',
#     'fat': 'French Fries (Regular)',
#     'carbs': 'French Fries (Regular)',
#     'restaurant': 'Corner Bakery Cafe'},
#    {'name': 'Cheese Curds (Large)',
#     'category': 'Cheese Curds (Large)',
#     'calories': 'Cheese Curds (Large)',
#     'fat': 'Cheese Curds (Large)',
#     'carbs': 'Cheese Curds (Large)',
#     'restaurant': 'Dairy Queen'},
#    {'name': 'Chocolate Milkshake (small)',
#     'category': 'Chocolate Milkshake (small)',
#     'calories': 'Chocolate Milkshake (small)',
#     'fat': 'Chocolate Milkshake (small)',
#     'carbs': 'Chocolate Milkshake (small)',
#     'restaurant': "Denny's"},
#    {'name': 'Orange Freeze (small)',
#     'category': 'Orange Freeze (small)',
#     'calories': 'Orange Freeze (small)',
#     'fat': 'Orange Freeze (small)',
#     'carbs': 'Orange Freeze (small)',
#     'restaurant': 'El Pollo Loco'},
#    {'name': 'A&amp;W® Diet Root Beer Float (small)',
#     'category': 'A&amp;W® Diet Root Beer Float (small)',
#     'calories': 'A&amp;W® Diet Root Beer Float (small)',
#     'fat': 'A&amp;W® Diet Root Beer Float (small)',
#     'carbs': 'A&amp;W® Diet Root Beer Float (small)',
#     'restaurant': 'FATZ'},
#    {'name': 'Strawberry Smoothee',
#     'category': 'Strawberry Smoothee',
#     'calories': 'Strawberry Smoothee',
#     'fat': 'Strawberry Smoothee',
#     'carbs': 'Strawberry Smoothee',
#     'restaurant': "Fazoli's"},
#    {'name': 'Limeade',
#     'category': 'Limeade',
#     'calories': 'Limeade',
#     'fat': 'Limeade',
#     'carbs': 'Limeade',
#     'restaurant': 'Five Guys Burgers and Fries'},
#    {'name': 'Cherry Limeade',
#     'category': 'Cherry Limeade',
#     'calories': 'Cherry Limeade',
#     'fat': 'Cherry Limeade',
#     'carbs': 'Cherry Limeade',
#     'restaurant': 'Golden Chick'},
#    {'name': 'Lemon Slushee',
#     'category': 'Lemon Slushee',
#     'calories': 'Lemon Slushee',
#     'fat': 'Lemon Slushee',
#     'carbs': 'Lemon Slushee',
#     'restaurant': "Hardee's"},
#    {'name': 'Blue Raspberry Slushee',
#     'category': 'Blue Raspberry Slushee',
#     'calories': 'Blue Raspberry Slushee',
#     'fat': 'Blue Raspberry Slushee',
#     'carbs': 'Blue Raspberry Slushee',
#     'restaurant': 'IHOP'},
#    {'name': 'A&amp;W® Diet Root Beer',
#     'category': 'A&amp;W® Diet Root Beer',
#     'calories': 'A&amp;W® Diet Root Beer',
#     'fat': 'A&amp;W® Diet Root Beer',
#     'carbs': 'A&amp;W® Diet Root Beer',
#     'restaurant': 'In-N-Out Burger'},
#    {'name': 'Grilled Chicken Sandwich',
#     'category': 'Grilled Chicken Sandwich',
#     'calories': 'Grilled Chicken Sandwich',
#     'fat': 'Grilled Chicken Sandwich',
#     'carbs': 'Grilled Chicken Sandwich',
#     'restaurant': 'Jack in the Box'},
#    {'name': 'French Fries (Large)',
#     'category': 'French Fries (Large)',
#     'calories': 'French Fries (Large)',
#     'fat': 'French Fries (Large)',
#     'carbs': 'French Fries (Large)',
#     'restaurant': 'Jimmy Johns'},
#    {'name': 'Chili',
#     'category': 'Chili',
#     'calories': 'Chili',
#     'fat': 'Chili',
#     'carbs': 'Chili',
#     'restaurant': "Joe's Crab Shack"},
#    {'name': 'Chocolate Milkshake (medium)',
#     'category': 'Chocolate Milkshake (medium)',
#     'calories': 'Chocolate Milkshake (medium)',
#     'fat': 'Chocolate Milkshake (medium)',
#     'carbs': 'Chocolate Milkshake (medium)',
#     'restaurant': 'KFC'},
#    {'name': 'Orange Freeze (medium)',
#     'category': 'Orange Freeze (medium)',
#     'calories': 'Orange Freeze (medium)',
#     'fat': 'Orange Freeze (medium)',
#     'carbs': 'Orange Freeze (medium)',
#     'restaurant': "McDonald's"},
#    {'name': 'A&amp;W® Diet Root Beer Float (medium)',
#     'category': 'A&amp;W® Diet Root Beer Float (medium)',
#     'calories': 'A&amp;W® Diet Root Beer Float (medium)',
#     'fat': 'A&amp;W® Diet Root Beer Float (medium)',
#     'carbs': 'A&amp;W® Diet Root Beer Float (medium)',
#     'restaurant': "O'Charley's"},
#    {'name': 'Orange Float (large)',
#     'category': 'Orange Float (large)',
#     'calories': 'Orange Float (large)',
#     'fat': 'Orange Float (large)',
#     'carbs': 'Orange Float (large)',
#     'restaurant': 'Olive Garden'},
#    {'name': "Reese's® Peanut Butter Fudge Blendrrr",
#     'category': "Reese's® Peanut Butter Fudge Blendrrr",
#     'calories': "Reese's® Peanut Butter Fudge Blendrrr",
#     'fat': "Reese's® Peanut Butter Fudge Blendrrr",
#     'carbs': "Reese's® Peanut Butter Fudge Blendrrr",
#     'restaurant': 'Outback Steakhouse'},
#    {'name': 'Limeade',
#     'category': 'Limeade',
#     'calories': 'Limeade',
#     'fat': 'Limeade',
#     'carbs': 'Limeade',
#     'restaurant': 'Panda Express'},
#    {'name': 'Cherry Limeade',
#     'category': 'Cherry Limeade',
#     'calories': 'Cherry Limeade',
#     'fat': 'Cherry Limeade',
#     'carbs': 'Cherry Limeade',
#     'restaurant': 'Panera Bread'},
#    {'name': 'Lemon Slushee',
#     'category': 'Lemon Slushee',
#     'calories': 'Lemon Slushee',
#     'fat': 'Lemon Slushee',
#     'carbs': 'Lemon Slushee',
#     'restaurant': "Popeye's"},
#    {'name': 'Blue Raspberry Slushee',
#     'category': 'Blue Raspberry Slushee',
#     'calories': 'Blue Raspberry Slushee',
#     'fat': 'Blue Raspberry Slushee',
#     'carbs': 'Blue Raspberry Slushee',
#     'restaurant': 'Quiznos'},
#    {'name': 'A&amp;W® Diet Root Beer',
#     'category': 'A&amp;W® Diet Root Beer',
#     'calories': 'A&amp;W® Diet Root Beer',
#     'fat': 'A&amp;W® Diet Root Beer',
#     'carbs': 'A&amp;W® Diet Root Beer',
#     'restaurant': 'Red Robin Gourmet Burgers'},
#    {'name': 'Original Double Cheeseburger',
#     'category': 'Original Double Cheeseburger',
#     'calories': 'Original Double Cheeseburger',
#     'fat': 'Original Double Cheeseburger',
#     'carbs': 'Original Double Cheeseburger',
#     'restaurant': "Romano's Macaroni Grill"},
#    {'name': 'Coney (Chili) Cheese Dog',
#     'category': 'Coney (Chili) Cheese Dog',
#     'calories': 'Coney (Chili) Cheese Dog',
#     'fat': 'Coney (Chili) Cheese Dog',
#     'carbs': 'Coney (Chili) Cheese Dog',
#     'restaurant': 'Ruby Tuesday'},
#    {'name': 'Breaded Onion Rings (Regular)',
#     'category': 'Breaded Onion Rings (Regular)',
#     'calories': 'Breaded Onion Rings (Regular)',
#     'fat': 'Breaded Onion Rings (Regular)',
#     'carbs': 'Breaded Onion Rings (Regular)',
#     'restaurant': 'Subway'},
#    {'name': 'Strawberry Milkshake (medium)',
#     'category': 'Strawberry Milkshake (medium)',
#     'calories': 'Strawberry Milkshake (medium)',
#     'fat': 'Strawberry Milkshake (medium)',
#     'carbs': 'Strawberry Milkshake (medium)',
#     'restaurant': 'Taco Bell'},
#    {'name': 'A&amp;W® Diet Root Beer Freeze (small)',
#     'category': 'A&amp;W® Diet Root Beer Freeze (small)',
#     'calories': 'A&amp;W® Diet Root Beer Freeze (small)',
#     'fat': 'A&amp;W® Diet Root Beer Freeze (small)',
#     'carbs': 'A&amp;W® Diet Root Beer Freeze (small)',
#     'restaurant': 'Taco Bueno'},
#    {'name': 'A&amp;W® Root Beer Float (small)',
#     'category': 'A&amp;W® Root Beer Float (small)',
#     'calories': 'A&amp;W® Root Beer Float (small)',
#     'fat': 'A&amp;W® Root Beer Float (small)',
#     'carbs': 'A&amp;W® Root Beer Float (small)',
#     'restaurant': "Wendy's"}]},
#  {'name': "Bojangle's Famous Chicken 'n Biscuits",
#   'href': 'restaurants/5.html',
#   'foods': [{'name': 'Original Bacon Double Cheeseburger',
#     'category': 'Original Bacon Double Cheeseburger',
#     'calories': 'Original Bacon Double Cheeseburger',
#     'fat': 'Original Bacon Double Cheeseburger',
#     'carbs': 'Original Bacon Double Cheeseburger',
#     'restaurant': "Applebee's"},
#    {'name': 'Coney (Chili) Dog',
#     'category': 'Coney (Chili) Dog',
#     'calories': 'Coney (Chili) Dog',
#     'fat': 'Coney (Chili) Dog',
#     'carbs': 'Coney (Chili) Dog',
#     'restaurant': "Arby's"},
#    {'name': 'Chili Fries',
#     'category': 'Chili Fries',
#     'calories': 'Chili Fries',
#     'fat': 'Chili Fries',
#     'carbs': 'Chili Fries',
#     'restaurant': 'Atlanta Bread Company'},
#    {'name': 'Strawberry Milkshake (small)',
#     'category': 'Strawberry Milkshake (small)',
#     'calories': 'Strawberry Milkshake (small)',
#     'fat': 'Strawberry Milkshake (small)',
#     'carbs': 'Strawberry Milkshake (small)',
#     'restaurant': "Bojangle's Famous Chicken 'n Biscuits"},
#    {'name': 'A&amp;W® Root Beer Freeze (large)',
#     'category': 'A&amp;W® Root Beer Freeze (large)',
#     'calories': 'A&amp;W® Root Beer Freeze (large)',
#     'fat': 'A&amp;W® Root Beer Freeze (large)',
#     'carbs': 'A&amp;W® Root Beer Freeze (large)',
#     'restaurant': 'Buffalo Wild Wings'},
#    {'name': 'Caramel Sundae',
#     'category': 'Caramel Sundae',
#     'calories': 'Caramel Sundae',
#     'fat': 'Caramel Sundae',
#     'carbs': 'Caramel Sundae',
#     'restaurant': 'Burger King'},
#    {'name': 'Strawberry Banana Smoothee',
#     'category': 'Strawberry Banana Smoothee',
#     'calories': 'Strawberry Banana Smoothee',
#     'fat': 'Strawberry Banana Smoothee',
#     'carbs': 'Strawberry Banana Smoothee',
#     'restaurant': "Captain D's"},
#    {'name': 'Chocolate Fudge Blendrrr',
#     'category': 'Chocolate Fudge Blendrrr',
#     'calories': 'Chocolate Fudge Blendrrr',
#     'fat': 'Chocolate Fudge Blendrrr',
#     'carbs': 'Chocolate Fudge Blendrrr',
#     'restaurant': "Carl's Jr."},
#    {'name': 'Strawberry Limeade',
#     'category': 'Strawberry Limeade',
#     'calories': 'Strawberry Limeade',
#     'fat': 'Strawberry Limeade',
#     'carbs': 'Strawberry Limeade',
#     'restaurant': "Charley's Grilled Subs"},
#    {'name': 'Watermelon Slushee',
#     'category': 'Watermelon Slushee',
#     'calories': 'Watermelon Slushee',
#     'fat': 'Watermelon Slushee',
#     'carbs': 'Watermelon Slushee',
#     'restaurant': 'Chick-fil-A'},
#    {'name': 'Lime Slushee',
#     'category': 'Lime Slushee',
#     'calories': 'Lime Slushee',
#     'fat': 'Lime Slushee',
#     'carbs': 'Lime Slushee',
#     'restaurant': "Chili's"},
#    {'name': 'A&amp;W® Root Beer',
#     'category': 'A&amp;W® Root Beer',
#     'calories': 'A&amp;W® Root Beer',
#     'fat': 'A&amp;W® Root Beer',
#     'carbs': 'A&amp;W® Root Beer',
#     'restaurant': 'Chipotle Mexican Grill'},
#    {'name': 'Cheeseburger',
#     'category': 'Cheeseburger',
#     'calories': 'Cheeseburger',
#     'fat': 'Cheeseburger',
#     'carbs': 'Cheeseburger',
#     'restaurant': "Church's"},
#    {'name': 'French Fries (Regular)',
#     'category': 'French Fries (Regular)',
#     'calories': 'French Fries (Regular)',
#     'fat': 'French Fries (Regular)',
#     'carbs': 'French Fries (Regular)',
#     'restaurant': 'Corner Bakery Cafe'},
#    {'name': 'Cheese Curds (Large)',
#     'category': 'Cheese Curds (Large)',
#     'calories': 'Cheese Curds (Large)',
#     'fat': 'Cheese Curds (Large)',
#     'carbs': 'Cheese Curds (Large)',
#     'restaurant': 'Dairy Queen'},
#    {'name': 'Chocolate Milkshake (small)',
#     'category': 'Chocolate Milkshake (small)',
#     'calories': 'Chocolate Milkshake (small)',
#     'fat': 'Chocolate Milkshake (small)',
#     'carbs': 'Chocolate Milkshake (small)',
#     'restaurant': "Denny's"},
#    {'name': 'Orange Freeze (small)',
#     'category': 'Orange Freeze (small)',
#     'calories': 'Orange Freeze (small)',
#     'fat': 'Orange Freeze (small)',
#     'carbs': 'Orange Freeze (small)',
#     'restaurant': 'El Pollo Loco'},
#    {'name': 'A&amp;W® Diet Root Beer Float (small)',
#     'category': 'A&amp;W® Diet Root Beer Float (small)',
#     'calories': 'A&amp;W® Diet Root Beer Float (small)',
#     'fat': 'A&amp;W® Diet Root Beer Float (small)',
#     'carbs': 'A&amp;W® Diet Root Beer Float (small)',
#     'restaurant': 'FATZ'},
#    {'name': 'Strawberry Smoothee',
#     'category': 'Strawberry Smoothee',
#     'calories': 'Strawberry Smoothee',
#     'fat': 'Strawberry Smoothee',
#     'carbs': 'Strawberry Smoothee',
#     'restaurant': "Fazoli's"},
#    {'name': 'Limeade',
#     'category': 'Limeade',
#     'calories': 'Limeade',
#     'fat': 'Limeade',
#     'carbs': 'Limeade',
#     'restaurant': 'Five Guys Burgers and Fries'},
#    {'name': 'Cherry Limeade',
#     'category': 'Cherry Limeade',
#     'calories': 'Cherry Limeade',
#     'fat': 'Cherry Limeade',
#     'carbs': 'Cherry Limeade',
#     'restaurant': 'Golden Chick'},
#    {'name': 'Lemon Slushee',
#     'category': 'Lemon Slushee',
#     'calories': 'Lemon Slushee',
#     'fat': 'Lemon Slushee',
#     'carbs': 'Lemon Slushee',
#     'restaurant': "Hardee's"},
#    {'name': 'Blue Raspberry Slushee',
#     'category': 'Blue Raspberry Slushee',
#     'calories': 'Blue Raspberry Slushee',
#     'fat': 'Blue Raspberry Slushee',
#     'carbs': 'Blue Raspberry Slushee',
#     'restaurant': 'IHOP'},
#    {'name': 'A&amp;W® Diet Root Beer',
#     'category': 'A&amp;W® Diet Root Beer',
#     'calories': 'A&amp;W® Diet Root Beer',
#     'fat': 'A&amp;W® Diet Root Beer',
#     'carbs': 'A&amp;W® Diet Root Beer',
#     'restaurant': 'In-N-Out Burger'},
#    {'name': 'Grilled Chicken Sandwich',
#     'category': 'Grilled Chicken Sandwich',
#     'calories': 'Grilled Chicken Sandwich',
#     'fat': 'Grilled Chicken Sandwich',
#     'carbs': 'Grilled Chicken Sandwich',
#     'restaurant': 'Jack in the Box'},
#    {'name': 'French Fries (Large)',
#     'category': 'French Fries (Large)',
#     'calories': 'French Fries (Large)',
#     'fat': 'French Fries (Large)',
#     'carbs': 'French Fries (Large)',
#     'restaurant': 'Jimmy Johns'},
#    {'name': 'Chili',
#     'category': 'Chili',
#     'calories': 'Chili',
#     'fat': 'Chili',
#     'carbs': 'Chili',
#     'restaurant': "Joe's Crab Shack"},
#    {'name': 'Chocolate Milkshake (medium)',
#     'category': 'Chocolate Milkshake (medium)',
#     'calories': 'Chocolate Milkshake (medium)',
#     'fat': 'Chocolate Milkshake (medium)',
#     'carbs': 'Chocolate Milkshake (medium)',
#     'restaurant': 'KFC'},
#    {'name': 'Orange Freeze (medium)',
#     'category': 'Orange Freeze (medium)',
#     'calories': 'Orange Freeze (medium)',
#     'fat': 'Orange Freeze (medium)',
#     'carbs': 'Orange Freeze (medium)',
#     'restaurant': "McDonald's"},
#    {'name': 'A&amp;W® Diet Root Beer Float (medium)',
#     'category': 'A&amp;W® Diet Root Beer Float (medium)',
#     'calories': 'A&amp;W® Diet Root Beer Float (medium)',
#     'fat': 'A&amp;W® Diet Root Beer Float (medium)',
#     'carbs': 'A&amp;W® Diet Root Beer Float (medium)',
#     'restaurant': "O'Charley's"},
#    {'name': 'Orange Float (large)',
#     'category': 'Orange Float (large)',
#     'calories': 'Orange Float (large)',
#     'fat': 'Orange Float (large)',
#     'carbs': 'Orange Float (large)',
#     'restaurant': 'Olive Garden'},
#    {'name': "Reese's® Peanut Butter Fudge Blendrrr",
#     'category': "Reese's® Peanut Butter Fudge Blendrrr",
#     'calories': "Reese's® Peanut Butter Fudge Blendrrr",
#     'fat': "Reese's® Peanut Butter Fudge Blendrrr",
#     'carbs': "Reese's® Peanut Butter Fudge Blendrrr",
#     'restaurant': 'Outback Steakhouse'},
#    {'name': 'Limeade',
#     'category': 'Limeade',
#     'calories': 'Limeade',
#     'fat': 'Limeade',
#     'carbs': 'Limeade',
#     'restaurant': 'Panda Express'},
#    {'name': 'Cherry Limeade',
#     'category': 'Cherry Limeade',
#     'calories': 'Cherry Limeade',
#     'fat': 'Cherry Limeade',
#     'carbs': 'Cherry Limeade',
#     'restaurant': 'Panera Bread'},
#    {'name': 'Lemon Slushee',
#     'category': 'Lemon Slushee',
#     'calories': 'Lemon Slushee',
#     'fat': 'Lemon Slushee',
#     'carbs': 'Lemon Slushee',
#     'restaurant': "Popeye's"},
#    {'name': 'Blue Raspberry Slushee',
#     'category': 'Blue Raspberry Slushee',
#     'calories': 'Blue Raspberry Slushee',
#     'fat': 'Blue Raspberry Slushee',
#     'carbs': 'Blue Raspberry Slushee',
#     'restaurant': 'Quiznos'},
#    {'name': 'A&amp;W® Diet Root Beer',
#     'category': 'A&amp;W® Diet Root Beer',
#     'calories': 'A&amp;W® Diet Root Beer',
#     'fat': 'A&amp;W® Diet Root Beer',
#     'carbs': 'A&amp;W® Diet Root Beer',
#     'restaurant': 'Red Robin Gourmet Burgers'},
#    {'name': 'Original Double Cheeseburger',
#     'category': 'Original Double Cheeseburger',
#     'calories': 'Original Double Cheeseburger',
#     'fat': 'Original Double Cheeseburger',
#     'carbs': 'Original Double Cheeseburger',
#     'restaurant': "Romano's Macaroni Grill"},
#    {'name': 'Coney (Chili) Cheese Dog',
#     'category': 'Coney (Chili) Cheese Dog',
#     'calories': 'Coney (Chili) Cheese Dog',
#     'fat': 'Coney (Chili) Cheese Dog',
#     'carbs': 'Coney (Chili) Cheese Dog',
#     'restaurant': 'Ruby Tuesday'},
#    {'name': 'Breaded Onion Rings (Regular)',
#     'category': 'Breaded Onion Rings (Regular)',
#     'calories': 'Breaded Onion Rings (Regular)',
#     'fat': 'Breaded Onion Rings (Regular)',
#     'carbs': 'Breaded Onion Rings (Regular)',
#     'restaurant': 'Subway'},
#    {'name': 'Strawberry Milkshake (medium)',
#     'category': 'Strawberry Milkshake (medium)',
#     'calories': 'Strawberry Milkshake (medium)',
#     'fat': 'Strawberry Milkshake (medium)',
#     'carbs': 'Strawberry Milkshake (medium)',
#     'restaurant': 'Taco Bell'},
#    {'name': 'A&amp;W® Diet Root Beer Freeze (small)',
#     'category': 'A&amp;W® Diet Root Beer Freeze (small)',
#     'calories': 'A&amp;W® Diet Root Beer Freeze (small)',
#     'fat': 'A&amp;W® Diet Root Beer Freeze (small)',
#     'carbs': 'A&amp;W® Diet Root Beer Freeze (small)',
#     'restaurant': 'Taco Bueno'},
#    {'name': 'A&amp;W® Root Beer Float (small)',
#     'category': 'A&amp;W® Root Beer Float (small)',
#     'calories': 'A&amp;W® Root Beer Float (small)',
#     'fat': 'A&amp;W® Root Beer Float (small)',
#     'carbs': 'A&amp;W® Root Beer Float (small)',
#     'restaurant': "Wendy's"}]},
#  {'name': 'Buffalo Wild Wings',
#   'href': 'restaurants/6.html',
#   'foods': [{'name': 'Original Bacon Double Cheeseburger',
#     'category': 'Original Bacon Double Cheeseburger',
#     'calories': 'Original Bacon Double Cheeseburger',
#     'fat': 'Original Bacon Double Cheeseburger',
#     'carbs': 'Original Bacon Double Cheeseburger',
#     'restaurant': "Applebee's"},
#    {'name': 'Coney (Chili) Dog',
#     'category': 'Coney (Chili) Dog',
#     'calories': 'Coney (Chili) Dog',
#     'fat': 'Coney (Chili) Dog',
#     'carbs': 'Coney (Chili) Dog',
#     'restaurant': "Arby's"},
#    {'name': 'Chili Fries',
#     'category': 'Chili Fries',
#     'calories': 'Chili Fries',
#     'fat': 'Chili Fries',
#     'carbs': 'Chili Fries',
#     'restaurant': 'Atlanta Bread Company'},
#    {'name': 'Strawberry Milkshake (small)',
#     'category': 'Strawberry Milkshake (small)',
#     'calories': 'Strawberry Milkshake (small)',
#     'fat': 'Strawberry Milkshake (small)',
#     'carbs': 'Strawberry Milkshake (small)',
#     'restaurant': "Bojangle's Famous Chicken 'n Biscuits"},
#    {'name': 'A&amp;W® Root Beer Freeze (large)',
#     'category': 'A&amp;W® Root Beer Freeze (large)',
#     'calories': 'A&amp;W® Root Beer Freeze (large)',
#     'fat': 'A&amp;W® Root Beer Freeze (large)',
#     'carbs': 'A&amp;W® Root Beer Freeze (large)',
#     'restaurant': 'Buffalo Wild Wings'},
#    {'name': 'Caramel Sundae',
#     'category': 'Caramel Sundae',
#     'calories': 'Caramel Sundae',
#     'fat': 'Caramel Sundae',
#     'carbs': 'Caramel Sundae',
#     'restaurant': 'Burger King'},
#    {'name': 'Strawberry Banana Smoothee',
#     'category': 'Strawberry Banana Smoothee',
#     'calories': 'Strawberry Banana Smoothee',
#     'fat': 'Strawberry Banana Smoothee',
#     'carbs': 'Strawberry Banana Smoothee',
#     'restaurant': "Captain D's"},
#    {'name': 'Chocolate Fudge Blendrrr',
#     'category': 'Chocolate Fudge Blendrrr',
#     'calories': 'Chocolate Fudge Blendrrr',
#     'fat': 'Chocolate Fudge Blendrrr',
#     'carbs': 'Chocolate Fudge Blendrrr',
#     'restaurant': "Carl's Jr."},
#    {'name': 'Strawberry Limeade',
#     'category': 'Strawberry Limeade',
#     'calories': 'Strawberry Limeade',
#     'fat': 'Strawberry Limeade',
#     'carbs': 'Strawberry Limeade',
#     'restaurant': "Charley's Grilled Subs"},
#    {'name': 'Watermelon Slushee',
#     'category': 'Watermelon Slushee',
#     'calories': 'Watermelon Slushee',
#     'fat': 'Watermelon Slushee',
#     'carbs': 'Watermelon Slushee',
#     'restaurant': 'Chick-fil-A'},
#    {'name': 'Lime Slushee',
#     'category': 'Lime Slushee',
#     'calories': 'Lime Slushee',
#     'fat': 'Lime Slushee',
#     'carbs': 'Lime Slushee',
#     'restaurant': "Chili's"},
#    {'name': 'A&amp;W® Root Beer',
#     'category': 'A&amp;W® Root Beer',
#     'calories': 'A&amp;W® Root Beer',
#     'fat': 'A&amp;W® Root Beer',
#     'carbs': 'A&amp;W® Root Beer',
#     'restaurant': 'Chipotle Mexican Grill'},
#    {'name': 'Cheeseburger',
#     'category': 'Cheeseburger',
#     'calories': 'Cheeseburger',
#     'fat': 'Cheeseburger',
#     'carbs': 'Cheeseburger',
#     'restaurant': "Church's"},
#    {'name': 'French Fries (Regular)',
#     'category': 'French Fries (Regular)',
#     'calories': 'French Fries (Regular)',
#     'fat': 'French Fries (Regular)',
#     'carbs': 'French Fries (Regular)',
#     'restaurant': 'Corner Bakery Cafe'},
#    {'name': 'Cheese Curds (Large)',
#     'category': 'Cheese Curds (Large)',
#     'calories': 'Cheese Curds (Large)',
#     'fat': 'Cheese Curds (Large)',
#     'carbs': 'Cheese Curds (Large)',
#     'restaurant': 'Dairy Queen'},
#    {'name': 'Chocolate Milkshake (small)',
#     'category': 'Chocolate Milkshake (small)',
#     'calories': 'Chocolate Milkshake (small)',
#     'fat': 'Chocolate Milkshake (small)',
#     'carbs': 'Chocolate Milkshake (small)',
#     'restaurant': "Denny's"},
#    {'name': 'Orange Freeze (small)',
#     'category': 'Orange Freeze (small)',
#     'calories': 'Orange Freeze (small)',
#     'fat': 'Orange Freeze (small)',
#     'carbs': 'Orange Freeze (small)',
#     'restaurant': 'El Pollo Loco'},
#    {'name': 'A&amp;W® Diet Root Beer Float (small)',
#     'category': 'A&amp;W® Diet Root Beer Float (small)',
#     'calories': 'A&amp;W® Diet Root Beer Float (small)',
#     'fat': 'A&amp;W® Diet Root Beer Float (small)',
#     'carbs': 'A&amp;W® Diet Root Beer Float (small)',
#     'restaurant': 'FATZ'},
#    {'name': 'Strawberry Smoothee',
#     'category': 'Strawberry Smoothee',
#     'calories': 'Strawberry Smoothee',
#     'fat': 'Strawberry Smoothee',
#     'carbs': 'Strawberry Smoothee',
#     'restaurant': "Fazoli's"},
#    {'name': 'Limeade',
#     'category': 'Limeade',
#     'calories': 'Limeade',
#     'fat': 'Limeade',
#     'carbs': 'Limeade',
#     'restaurant': 'Five Guys Burgers and Fries'},
#    {'name': 'Cherry Limeade',
#     'category': 'Cherry Limeade',
#     'calories': 'Cherry Limeade',
#     'fat': 'Cherry Limeade',
#     'carbs': 'Cherry Limeade',
#     'restaurant': 'Golden Chick'},
#    {'name': 'Lemon Slushee',
#     'category': 'Lemon Slushee',
#     'calories': 'Lemon Slushee',
#     'fat': 'Lemon Slushee',
#     'carbs': 'Lemon Slushee',
#     'restaurant': "Hardee's"},
#    {'name': 'Blue Raspberry Slushee',
#     'category': 'Blue Raspberry Slushee',
#     'calories': 'Blue Raspberry Slushee',
#     'fat': 'Blue Raspberry Slushee',
#     'carbs': 'Blue Raspberry Slushee',
#     'restaurant': 'IHOP'},
#    {'name': 'A&amp;W® Diet Root Beer',
#     'category': 'A&amp;W® Diet Root Beer',
#     'calories': 'A&amp;W® Diet Root Beer',
#     'fat': 'A&amp;W® Diet Root Beer',
#     'carbs': 'A&amp;W® Diet Root Beer',
#     'restaurant': 'In-N-Out Burger'},
#    {'name': 'Grilled Chicken Sandwich',
#     'category': 'Grilled Chicken Sandwich',
#     'calories': 'Grilled Chicken Sandwich',
#     'fat': 'Grilled Chicken Sandwich',
#     'carbs': 'Grilled Chicken Sandwich',
#     'restaurant': 'Jack in the Box'},
#    {'name': 'French Fries (Large)',
#     'category': 'French Fries (Large)',
#     'calories': 'French Fries (Large)',
#     'fat': 'French Fries (Large)',
#     'carbs': 'French Fries (Large)',
#     'restaurant': 'Jimmy Johns'},
#    {'name': 'Chili',
#     'category': 'Chili',
#     'calories': 'Chili',
#     'fat': 'Chili',
#     'carbs': 'Chili',
#     'restaurant': "Joe's Crab Shack"},
#    {'name': 'Chocolate Milkshake (medium)',
#     'category': 'Chocolate Milkshake (medium)',
#     'calories': 'Chocolate Milkshake (medium)',
#     'fat': 'Chocolate Milkshake (medium)',
#     'carbs': 'Chocolate Milkshake (medium)',
#     'restaurant': 'KFC'},
#    {'name': 'Orange Freeze (medium)',
#     'category': 'Orange Freeze (medium)',
#     'calories': 'Orange Freeze (medium)',
#     'fat': 'Orange Freeze (medium)',
#     'carbs': 'Orange Freeze (medium)',
#     'restaurant': "McDonald's"},
#    {'name': 'A&amp;W® Diet Root Beer Float (medium)',
#     'category': 'A&amp;W® Diet Root Beer Float (medium)',
#     'calories': 'A&amp;W® Diet Root Beer Float (medium)',
#     'fat': 'A&amp;W® Diet Root Beer Float (medium)',
#     'carbs': 'A&amp;W® Diet Root Beer Float (medium)',
#     'restaurant': "O'Charley's"},
#    {'name': 'Orange Float (large)',
#     'category': 'Orange Float (large)',
#     'calories': 'Orange Float (large)',
#     'fat': 'Orange Float (large)',
#     'carbs': 'Orange Float (large)',
#     'restaurant': 'Olive Garden'},
#    {'name': "Reese's® Peanut Butter Fudge Blendrrr",
#     'category': "Reese's® Peanut Butter Fudge Blendrrr",
#     'calories': "Reese's® Peanut Butter Fudge Blendrrr",
#     'fat': "Reese's® Peanut Butter Fudge Blendrrr",
#     'carbs': "Reese's® Peanut Butter Fudge Blendrrr",
#     'restaurant': 'Outback Steakhouse'},
#    {'name': 'Limeade',
# ...
#     'restaurant': 'FATZ'},
#    {'name': 'Strawberry Smoothee',
#     'category': 'Strawberry Smoothee',
#     'calories': 'Strawberry Smoothee',
#     'fat': 'Strawberry Smoothee',
#     'carbs': 'Strawberry Smoothee',
#     'restaurant': "Fazoli's"},
#    {'name': 'Limeade',
#     'category': 'Limeade',
#     'calories': 'Limeade',
#     'fat': 'Limeade',
#     'carbs': 'Limeade',
#     'restaurant': 'Five Guys Burgers and Fries'},
#    {'name': 'Cherry Limeade',
#     'category': 'Cherry Limeade',
#     'calories': 'Cherry Limeade',
#     'fat': 'Cherry Limeade',
#     'carbs': 'Cherry Limeade',
#     'restaurant': 'Golden Chick'},
#    {'name': 'Lemon Slushee',
#     'category': 'Lemon Slushee',
#     'calories': 'Lemon Slushee',
#     'fat': 'Lemon Slushee',
#     'carbs': 'Lemon Slushee',
#     'restaurant': "Hardee's"},
#    {'name': 'Blue Raspberry Slushee',
#     'category': 'Blue Raspberry Slushee',
#     'calories': 'Blue Raspberry Slushee',
#     'fat': 'Blue Raspberry Slushee',
#     'carbs': 'Blue Raspberry Slushee',
#     'restaurant': 'IHOP'},
#    {'name': 'A&amp;W® Diet Root Beer',
#     'category': 'A&amp;W® Diet Root Beer',
#     'calories': 'A&amp;W® Diet Root Beer',
#     'fat': 'A&amp;W® Diet Root Beer',
#     'carbs': 'A&amp;W® Diet Root Beer',
#     'restaurant': 'In-N-Out Burger'},
#    {'name': 'Grilled Chicken Sandwich',
#     'category': 'Grilled Chicken Sandwich',
#     'calories': 'Grilled Chicken Sandwich',
#     'fat': 'Grilled Chicken Sandwich',
#     'carbs': 'Grilled Chicken Sandwich',
#     'restaurant': 'Jack in the Box'},
#    {'name': 'French Fries (Large)',
#     'category': 'French Fries (Large)',
#     'calories': 'French Fries (Large)',
#     'fat': 'French Fries (Large)',
#     'carbs': 'French Fries (Large)',
#     'restaurant': 'Jimmy Johns'},
#    {'name': 'Chili',
#     'category': 'Chili',
#     'calories': 'Chili',
#     'fat': 'Chili',
#     'carbs': 'Chili',
#     'restaurant': "Joe's Crab Shack"},
#    {'name': 'Chocolate Milkshake (medium)',
#     'category': 'Chocolate Milkshake (medium)',
#     'calories': 'Chocolate Milkshake (medium)',
#     'fat': 'Chocolate Milkshake (medium)',
#     'carbs': 'Chocolate Milkshake (medium)',
#     'restaurant': 'KFC'},
#    {'name': 'Orange Freeze (medium)',
#     'category': 'Orange Freeze (medium)',
#     'calories': 'Orange Freeze (medium)',
#     'fat': 'Orange Freeze (medium)',
#     'carbs': 'Orange Freeze (medium)',
#     'restaurant': "McDonald's"},
#    {'name': 'A&amp;W® Diet Root Beer Float (medium)',
#     'category': 'A&amp;W® Diet Root Beer Float (medium)',
#     'calories': 'A&amp;W® Diet Root Beer Float (medium)',
#     'fat': 'A&amp;W® Diet Root Beer Float (medium)',
#     'carbs': 'A&amp;W® Diet Root Beer Float (medium)',
#     'restaurant': "O'Charley's"},
#    {'name': 'Orange Float (large)',
#     'category': 'Orange Float (large)',
#     'calories': 'Orange Float (large)',
#     'fat': 'Orange Float (large)',
#     'carbs': 'Orange Float (large)',
#     'restaurant': 'Olive Garden'},
#    {'name': "Reese's® Peanut Butter Fudge Blendrrr",
#     'category': "Reese's® Peanut Butter Fudge Blendrrr",
#     'calories': "Reese's® Peanut Butter Fudge Blendrrr",
#     'fat': "Reese's® Peanut Butter Fudge Blendrrr",
#     'carbs': "Reese's® Peanut Butter Fudge Blendrrr",
#     'restaurant': 'Outback Steakhouse'},
#    {'name': 'Limeade',
#     'category': 'Limeade',
#     'calories': 'Limeade',
#     'fat': 'Limeade',
#     'carbs': 'Limeade',
#     'restaurant': 'Panda Express'},
#    {'name': 'Cherry Limeade',
#     'category': 'Cherry Limeade',
#     'calories': 'Cherry Limeade',
#     'fat': 'Cherry Limeade',
#     'carbs': 'Cherry Limeade',
#     'restaurant': 'Panera Bread'},
#    {'name': 'Lemon Slushee',
#     'category': 'Lemon Slushee',
#     'calories': 'Lemon Slushee',
#     'fat': 'Lemon Slushee',
#     'carbs': 'Lemon Slushee',
#     'restaurant': "Popeye's"},
#    {'name': 'Blue Raspberry Slushee',
#     'category': 'Blue Raspberry Slushee',
#     'calories': 'Blue Raspberry Slushee',
#     'fat': 'Blue Raspberry Slushee',
#     'carbs': 'Blue Raspberry Slushee',
#     'restaurant': 'Quiznos'},
#    {'name': 'A&amp;W® Diet Root Beer',
#     'category': 'A&amp;W® Diet Root Beer',
#     'calories': 'A&amp;W® Diet Root Beer',
#     'fat': 'A&amp;W® Diet Root Beer',
#     'carbs': 'A&amp;W® Diet Root Beer',
#     'restaurant': 'Red Robin Gourmet Burgers'},
#    {'name': 'Original Double Cheeseburger',
#     'category': 'Original Double Cheeseburger',
#     'calories': 'Original Double Cheeseburger',
#     'fat': 'Original Double Cheeseburger',
#     'carbs': 'Original Double Cheeseburger',
#     'restaurant': "Romano's Macaroni Grill"},
#    {'name': 'Coney (Chili) Cheese Dog',
#     'category': 'Coney (Chili) Cheese Dog',
#     'calories': 'Coney (Chili) Cheese Dog',
#     'fat': 'Coney (Chili) Cheese Dog',
#     'carbs': 'Coney (Chili) Cheese Dog',
#     'restaurant': 'Ruby Tuesday'},
#    {'name': 'Breaded Onion Rings (Regular)',
#     'category': 'Breaded Onion Rings (Regular)',
#     'calories': 'Breaded Onion Rings (Regular)',
#     'fat': 'Breaded Onion Rings (Regular)',
#     'carbs': 'Breaded Onion Rings (Regular)',
#     'restaurant': 'Subway'},
#    {'name': 'Strawberry Milkshake (medium)',
#     'category': 'Strawberry Milkshake (medium)',
#     'calories': 'Strawberry Milkshake (medium)',
#     'fat': 'Strawberry Milkshake (medium)',
#     'carbs': 'Strawberry Milkshake (medium)',
#     'restaurant': 'Taco Bell'},
#    {'name': 'A&amp;W® Diet Root Beer Freeze (small)',
#     'category': 'A&amp;W® Diet Root Beer Freeze (small)',
#     'calories': 'A&amp;W® Diet Root Beer Freeze (small)',
#     'fat': 'A&amp;W® Diet Root Beer Freeze (small)',
#     'carbs': 'A&amp;W® Diet Root Beer Freeze (small)',
#     'restaurant': 'Taco Bueno'},
#    {'name': 'A&amp;W® Root Beer Float (small)',
#     'category': 'A&amp;W® Root Beer Float (small)',
#     'calories': 'A&amp;W® Root Beer Float (small)',
#     'fat': 'A&amp;W® Root Beer Float (small)',
#     'carbs': 'A&amp;W® Root Beer Float (small)',
#     'restaurant': "Wendy's"}]},
#  {'name': "Wendy's",
#   'href': 'restaurants/44.html',
#   'foods': [{'name': 'Original Bacon Double Cheeseburger',
#     'category': 'Original Bacon Double Cheeseburger',
#     'calories': 'Original Bacon Double Cheeseburger',
#     'fat': 'Original Bacon Double Cheeseburger',
#     'carbs': 'Original Bacon Double Cheeseburger',
#     'restaurant': "Applebee's"},
#    {'name': 'Coney (Chili) Dog',
#     'category': 'Coney (Chili) Dog',
#     'calories': 'Coney (Chili) Dog',
#     'fat': 'Coney (Chili) Dog',
#     'carbs': 'Coney (Chili) Dog',
#     'restaurant': "Arby's"},
#    {'name': 'Chili Fries',
#     'category': 'Chili Fries',
#     'calories': 'Chili Fries',
#     'fat': 'Chili Fries',
#     'carbs': 'Chili Fries',
#     'restaurant': 'Atlanta Bread Company'},
#    {'name': 'Strawberry Milkshake (small)',
#     'category': 'Strawberry Milkshake (small)',
#     'calories': 'Strawberry Milkshake (small)',
#     'fat': 'Strawberry Milkshake (small)',
#     'carbs': 'Strawberry Milkshake (small)',
#     'restaurant': "Bojangle's Famous Chicken 'n Biscuits"},
#    {'name': 'A&amp;W® Root Beer Freeze (large)',
#     'category': 'A&amp;W® Root Beer Freeze (large)',
#     'calories': 'A&amp;W® Root Beer Freeze (large)',
#     'fat': 'A&amp;W® Root Beer Freeze (large)',
#     'carbs': 'A&amp;W® Root Beer Freeze (large)',
#     'restaurant': 'Buffalo Wild Wings'},
#    {'name': 'Caramel Sundae',
#     'category': 'Caramel Sundae',
#     'calories': 'Caramel Sundae',
#     'fat': 'Caramel Sundae',
#     'carbs': 'Caramel Sundae',
#     'restaurant': 'Burger King'},
#    {'name': 'Strawberry Banana Smoothee',
#     'category': 'Strawberry Banana Smoothee',
#     'calories': 'Strawberry Banana Smoothee',
#     'fat': 'Strawberry Banana Smoothee',
#     'carbs': 'Strawberry Banana Smoothee',
#     'restaurant': "Captain D's"},
#    {'name': 'Chocolate Fudge Blendrrr',
#     'category': 'Chocolate Fudge Blendrrr',
#     'calories': 'Chocolate Fudge Blendrrr',
#     'fat': 'Chocolate Fudge Blendrrr',
#     'carbs': 'Chocolate Fudge Blendrrr',
#     'restaurant': "Carl's Jr."},
#    {'name': 'Strawberry Limeade',
#     'category': 'Strawberry Limeade',
#     'calories': 'Strawberry Limeade',
#     'fat': 'Strawberry Limeade',
#     'carbs': 'Strawberry Limeade',
#     'restaurant': "Charley's Grilled Subs"},
#    {'name': 'Watermelon Slushee',
#     'category': 'Watermelon Slushee',
#     'calories': 'Watermelon Slushee',
#     'fat': 'Watermelon Slushee',
#     'carbs': 'Watermelon Slushee',
#     'restaurant': 'Chick-fil-A'},
#    {'name': 'Lime Slushee',
#     'category': 'Lime Slushee',
#     'calories': 'Lime Slushee',
#     'fat': 'Lime Slushee',
#     'carbs': 'Lime Slushee',
#     'restaurant': "Chili's"},
#    {'name': 'A&amp;W® Root Beer',
#     'category': 'A&amp;W® Root Beer',
#     'calories': 'A&amp;W® Root Beer',
#     'fat': 'A&amp;W® Root Beer',
#     'carbs': 'A&amp;W® Root Beer',
#     'restaurant': 'Chipotle Mexican Grill'},
#    {'name': 'Cheeseburger',
#     'category': 'Cheeseburger',
#     'calories': 'Cheeseburger',
#     'fat': 'Cheeseburger',
#     'carbs': 'Cheeseburger',
#     'restaurant': "Church's"},
#    {'name': 'French Fries (Regular)',
#     'category': 'French Fries (Regular)',
#     'calories': 'French Fries (Regular)',
#     'fat': 'French Fries (Regular)',
#     'carbs': 'French Fries (Regular)',
#     'restaurant': 'Corner Bakery Cafe'},
#    {'name': 'Cheese Curds (Large)',
#     'category': 'Cheese Curds (Large)',
#     'calories': 'Cheese Curds (Large)',
#     'fat': 'Cheese Curds (Large)',
#     'carbs': 'Cheese Curds (Large)',
#     'restaurant': 'Dairy Queen'},
#    {'name': 'Chocolate Milkshake (small)',
#     'category': 'Chocolate Milkshake (small)',
#     'calories': 'Chocolate Milkshake (small)',
#     'fat': 'Chocolate Milkshake (small)',
#     'carbs': 'Chocolate Milkshake (small)',
#     'restaurant': "Denny's"},
#    {'name': 'Orange Freeze (small)',
#     'category': 'Orange Freeze (small)',
#     'calories': 'Orange Freeze (small)',
#     'fat': 'Orange Freeze (small)',
#     'carbs': 'Orange Freeze (small)',
#     'restaurant': 'El Pollo Loco'},
#    {'name': 'A&amp;W® Diet Root Beer Float (small)',
#     'category': 'A&amp;W® Diet Root Beer Float (small)',
#     'calories': 'A&amp;W® Diet Root Beer Float (small)',
#     'fat': 'A&amp;W® Diet Root Beer Float (small)',
#     'carbs': 'A&amp;W® Diet Root Beer Float (small)',
#     'restaurant': 'FATZ'},
#    {'name': 'Strawberry Smoothee',
#     'category': 'Strawberry Smoothee',
#     'calories': 'Strawberry Smoothee',
#     'fat': 'Strawberry Smoothee',
#     'carbs': 'Strawberry Smoothee',
#     'restaurant': "Fazoli's"},
#    {'name': 'Limeade',
#     'category': 'Limeade',
#     'calories': 'Limeade',
#     'fat': 'Limeade',
#     'carbs': 'Limeade',
#     'restaurant': 'Five Guys Burgers and Fries'},
#    {'name': 'Cherry Limeade',
#     'category': 'Cherry Limeade',
#     'calories': 'Cherry Limeade',
#     'fat': 'Cherry Limeade',
#     'carbs': 'Cherry Limeade',
#     'restaurant': 'Golden Chick'},
#    {'name': 'Lemon Slushee',
#     'category': 'Lemon Slushee',
#     'calories': 'Lemon Slushee',
#     'fat': 'Lemon Slushee',
#     'carbs': 'Lemon Slushee',
#     'restaurant': "Hardee's"},
#    {'name': 'Blue Raspberry Slushee',
#     'category': 'Blue Raspberry Slushee',
#     'calories': 'Blue Raspberry Slushee',
#     'fat': 'Blue Raspberry Slushee',
#     'carbs': 'Blue Raspberry Slushee',
#     'restaurant': 'IHOP'},
#    {'name': 'A&amp;W® Diet Root Beer',
#     'category': 'A&amp;W® Diet Root Beer',
#     'calories': 'A&amp;W® Diet Root Beer',
#     'fat': 'A&amp;W® Diet Root Beer',
#     'carbs': 'A&amp;W® Diet Root Beer',
#     'restaurant': 'In-N-Out Burger'},
#    {'name': 'Grilled Chicken Sandwich',
#     'category': 'Grilled Chicken Sandwich',
#     'calories': 'Grilled Chicken Sandwich',
#     'fat': 'Grilled Chicken Sandwich',
#     'carbs': 'Grilled Chicken Sandwich',
#     'restaurant': 'Jack in the Box'},
#    {'name': 'French Fries (Large)',
#     'category': 'French Fries (Large)',
#     'calories': 'French Fries (Large)',
#     'fat': 'French Fries (Large)',
#     'carbs': 'French Fries (Large)',
#     'restaurant': 'Jimmy Johns'},
#    {'name': 'Chili',
#     'category': 'Chili',
#     'calories': 'Chili',
#     'fat': 'Chili',
#     'carbs': 'Chili',
#     'restaurant': "Joe's Crab Shack"},
#    {'name': 'Chocolate Milkshake (medium)',
#     'category': 'Chocolate Milkshake (medium)',
#     'calories': 'Chocolate Milkshake (medium)',
#     'fat': 'Chocolate Milkshake (medium)',
#     'carbs': 'Chocolate Milkshake (medium)',
#     'restaurant': 'KFC'},
#    {'name': 'Orange Freeze (medium)',
#     'category': 'Orange Freeze (medium)',
#     'calories': 'Orange Freeze (medium)',
#     'fat': 'Orange Freeze (medium)',
#     'carbs': 'Orange Freeze (medium)',
#     'restaurant': "McDonald's"},
#    {'name': 'A&amp;W® Diet Root Beer Float (medium)',
#     'category': 'A&amp;W® Diet Root Beer Float (medium)',
#     'calories': 'A&amp;W® Diet Root Beer Float (medium)',
#     'fat': 'A&amp;W® Diet Root Beer Float (medium)',
#     'carbs': 'A&amp;W® Diet Root Beer Float (medium)',
#     'restaurant': "O'Charley's"},
#    {'name': 'Orange Float (large)',
#     'category': 'Orange Float (large)',
#     'calories': 'Orange Float (large)',
#     'fat': 'Orange Float (large)',
#     'carbs': 'Orange Float (large)',
#     'restaurant': 'Olive Garden'},
#    {'name': "Reese's® Peanut Butter Fudge Blendrrr",
#     'category': "Reese's® Peanut Butter Fudge Blendrrr",
#     'calories': "Reese's® Peanut Butter Fudge Blendrrr",
#     'fat': "Reese's® Peanut Butter Fudge Blendrrr",
#     'carbs': "Reese's® Peanut Butter Fudge Blendrrr",
#     'restaurant': 'Outback Steakhouse'},
#    {'name': 'Limeade',
#     'category': 'Limeade',
#     'calories': 'Limeade',
#     'fat': 'Limeade',
#     'carbs': 'Limeade',
#     'restaurant': 'Panda Express'},
#    {'name': 'Cherry Limeade',
#     'category': 'Cherry Limeade',
#     'calories': 'Cherry Limeade',
#     'fat': 'Cherry Limeade',
#     'carbs': 'Cherry Limeade',
#     'restaurant': 'Panera Bread'},
#    {'name': 'Lemon Slushee',
#     'category': 'Lemon Slushee',
#     'calories': 'Lemon Slushee',
#     'fat': 'Lemon Slushee',
#     'carbs': 'Lemon Slushee',
#     'restaurant': "Popeye's"},
#    {'name': 'Blue Raspberry Slushee',
#     'category': 'Blue Raspberry Slushee',
#     'calories': 'Blue Raspberry Slushee',
#     'fat': 'Blue Raspberry Slushee',
#     'carbs': 'Blue Raspberry Slushee',
#     'restaurant': 'Quiznos'},
#    {'name': 'A&amp;W® Diet Root Beer',
#     'category': 'A&amp;W® Diet Root Beer',
#     'calories': 'A&amp;W® Diet Root Beer',
#     'fat': 'A&amp;W® Diet Root Beer',
#     'carbs': 'A&amp;W® Diet Root Beer',
#     'restaurant': 'Red Robin Gourmet Burgers'},
#    {'name': 'Original Double Cheeseburger',
#     'category': 'Original Double Cheeseburger',
#     'calories': 'Original Double Cheeseburger',
#     'fat': 'Original Double Cheeseburger',
#     'carbs': 'Original Double Cheeseburger',
#     'restaurant': "Romano's Macaroni Grill"},
#    {'name': 'Coney (Chili) Cheese Dog',
#     'category': 'Coney (Chili) Cheese Dog',
#     'calories': 'Coney (Chili) Cheese Dog',
#     'fat': 'Coney (Chili) Cheese Dog',
#     'carbs': 'Coney (Chili) Cheese Dog',
#     'restaurant': 'Ruby Tuesday'},
#    {'name': 'Breaded Onion Rings (Regular)',
#     'category': 'Breaded Onion Rings (Regular)',
#     'calories': 'Breaded Onion Rings (Regular)',
#     'fat': 'Breaded Onion Rings (Regular)',
#     'carbs': 'Breaded Onion Rings (Regular)',
#     'restaurant': 'Subway'},
#    {'name': 'Strawberry Milkshake (medium)',
#     'category': 'Strawberry Milkshake (medium)',
#     'calories': 'Strawberry Milkshake (medium)',
#     'fat': 'Strawberry Milkshake (medium)',
#     'carbs': 'Strawberry Milkshake (medium)',
#     'restaurant': 'Taco Bell'},
#    {'name': 'A&amp;W® Diet Root Beer Freeze (small)',
#     'category': 'A&amp;W® Diet Root Beer Freeze (small)',
#     'calories': 'A&amp;W® Diet Root Beer Freeze (small)',
#     'fat': 'A&amp;W® Diet Root Beer Freeze (small)',
#     'carbs': 'A&amp;W® Diet Root Beer Freeze (small)',
#     'restaurant': 'Taco Bueno'},
#    {'name': 'A&amp;W® Root Beer Float (small)',
#     'category': 'A&amp;W® Root Beer Float (small)',
#     'calories': 'A&amp;W® Root Beer Float (small)',
#     'fat': 'A&amp;W® Root Beer Float (small)',
#     'carbs': 'A&amp;W® Root Beer Float (small)',
#     'restaurant': "Wendy's"}]}]

# %% [markdown]
# ### Step 3: Scraping each restaurant's page and create a single list of food dictionaries using the `href`

# %%
href_list = [results_list[i]['href'] for i in range (len(results_list))]

# %%
home_url = "https://pages.git.generalassemb.ly/rldaggie/for-scraping/"

# %%
calories': '0',
        'carbs': '0',
        'category': 'Drinks',
        'fat': '0',
        'name': 'A&W® Diet Root Beer',
        'restaurant': 'A&W Restaurants'
    },

# %%
for x in range(len(href_list)):
    req = requests.get(home_url + href_list[x])
    soup = BeautifulSoup(req.content, 'lxml')
    table_soup = soup.find_all('tr')
    foods = []
    
    for i in range(1, (len(table_soup))):
        food = {}
        food['calories'] = str(table_soup[i]).split('<td>')[3].split('</td>')[0]
        food['carbs'] = str(table_soup[i]).split('<td>')[5].split('</td>')[0]
        food['category'] = str(table_soup[i]).split('<td>')[2].split('</td>')[0]
        food['fat'] = str(table_soup[i]).split('<td>')[4].split('</td>')[0]
        food['name'] = str(table_soup[i]).split('<td>')[1].split('</td>')[0]
        food['restaurant'] = results_list[x]['name']

        foods.append(food)
        
    results_list[x]['foods'] = foods

# %%
foods
# Out:
# [{'calories': '670',
#   'carbs': '41',
#   'category': 'Burgers',
#   'fat': '37',
#   'name': 'Son of Baconator®',
#   'restaurant': "Wendy's"},
#  {'calories': '270',
#   'carbs': '14',
#   'category': 'Chicken',
#   'fat': '18',
#   'name': '6-piece Chicken Nuggets',
#   'restaurant': "Wendy's"},
#  {'calories': '310',
#   'carbs': '40',
#   'category': 'French Fries',
#   'fat': '15',
#   'name': 'Small French Fries',
#   'restaurant': "Wendy's"},
#  {'calories': '780',
#   'carbs': '40',
#   'category': 'Salads',
#   'fat': '51',
#   'name': 'Spicy Chicken Caesar Salad',
#   'restaurant': "Wendy's"},
#  {'calories': '290',
#   'carbs': '48',
#   'category': 'Shakes',
#   'fat': '7',
#   'name': 'Small Original Chocolate Frosty™',
#   'restaurant': "Wendy's"},
#  {'calories': '560',
#   'carbs': '93',
#   'category': 'Shakes',
#   'fat': '14',
#   'name': 'Large Vanilla Frosty™',
#   'restaurant': "Wendy's"},
#  {'calories': '290',
#   'carbs': '53',
#   'category': 'Shakes',
#   'fat': '6',
#   'name': 'Vanilla Frosty Waffle Cone',
#   'restaurant': "Wendy's"},
#  {'calories': '460',
#   'carbs': '27',
#   'category': 'Burgers',
#   'fat': '25',
#   'name': 'Double Stack™',
#   'restaurant': "Wendy's"},
#  {'calories': '290',
#   'carbs': '26',
#   'category': 'Burgers',
#   'fat': '13',
#   'name': 'Jr. Cheeseburger',
#   'restaurant': "Wendy's"},
#  {'calories': '40',
#   'carbs': '9',
#   'category': 'Desserts',
#   'fat': '0',
#   'name': 'Apple Slices',
#   'restaurant': "Wendy's"},
#  {'calories': '380',
#   'carbs': '33',
#   'category': 'Salads',
#   'fat': '13',
#   'name': 'Asian Cashew Chicken Salad',
#   'restaurant': "Wendy's"},
#  {'calories': '350',
#   'carbs': '28',
#   'category': 'Burgers',
#   'fat': '19',
#   'name': 'Jr. Cheeseburger Deluxe',
#   'restaurant': "Wendy's"},
#  {'calories': '450',
#   'carbs': '24',
#   'category': 'Chicken',
#   'fat': '30',
#   'name': '10-piece Chicken Nuggets',
#   'restaurant': "Wendy's"},
#  {'calories': '500',
#   'carbs': '65',
#   'category': 'French Fries',
#   'fat': '24',
#   'name': 'Large French Fries',
#   'restaurant': "Wendy's"},
#  {'calories': '200',
#   'carbs': '19',
#   'category': 'Salads',
#   'fat': '13',
#   'name': 'Garden Side Salad',
#   'restaurant': "Wendy's"},
#  {'calories': '540',
#   'carbs': '66',
#   'category': 'Sides',
#   'fat': '21',
#   'name': 'Bacon Cheese Potato',
#   'restaurant': "Wendy's"},
#  {'calories': '260',
#   'carbs': '25',
#   'category': 'Burgers',
#   'fat': '10',
#   'name': 'Jr. Hamburger',
#   'restaurant': "Wendy's"},
#  {'calories': '430',
#   'carbs': '23',
#   'category': 'Chicken',
#   'fat': '28',
#   'name': '10-piece Spicy Chicken Nuggets',
#   'restaurant': "Wendy's"},
#  {'calories': '530',
#   'carbs': '55',
#   'category': 'French Fries',
#   'fat': '28',
#   'name': 'Chili Cheese Fries',
#   'restaurant': "Wendy's"},
#  {'calories': '250',
#   'carbs': '18',
#   'category': 'Salads',
#   'fat': '17',
#   'name': 'Caesar Side Salad',
#   'restaurant': "Wendy's"},
#  {'calories': '410',
#   'carbs': '31',
#   'category': 'Wraps',
#   'fat': '24',
#   'name': 'Crispy Chicken Caesar Wrap',
#   'restaurant': "Wendy's"},
#  {'calories': '390',
#   'carbs': '26',
#   'category': 'Burgers',
#   'fat': '22',
#   'name': 'JBC (Jr. Bacon Cheeseburger)',
#   'restaurant': "Wendy's"},
#  {'calories': '260',
#   'carbs': '14',
#   'category': 'Chicken',
#   'fat': '17',
#   'name': '6-piece Spicy Chicken Nuggets',
#   'restaurant': "Wendy's"},
#  {'calories': '410',
#   'carbs': '52',
#   'category': 'French Fries',
#   'fat': '20',
#   'name': 'Medium French Fries',
#   'restaurant': "Wendy's"},
#  {'calories': '440',
#   'carbs': '28',
#   'category': 'Salads',
#   'fat': '27',
#   'name': 'Spicy Chicken Caesar Salad Half-Size',
#   'restaurant': "Wendy's"},
#  {'calories': '440',
#   'carbs': '67',
#   'category': 'Sides',
#   'fat': '14',
#   'name': 'Broccoli Cheese Potato',
#   'restaurant': "Wendy's"},
#  {'calories': '540',
#   'carbs': '97',
#   'category': 'Shakes',
#   'fat': '12',
#   'name': 'Small Strawberry Frosty™ Shake',
#   'restaurant': "Wendy's"},
#  {'calories': '300',
#   'carbs': '54',
#   'category': 'Shakes',
#   'fat': '6',
#   'name': 'Chocolate Frosty Waffle Cone',
#   'restaurant': "Wendy's"},
#  {'calories': '940',
#   'carbs': '41',
#   'category': 'Burgers',
#   'fat': '56',
#   'name': 'Baconator®',
#   'restaurant': "Wendy's"},
#  {'calories': '170',
#   'carbs': '9',
#   'category': 'Chicken',
#   'fat': '11',
#   'name': '4-piece Spicy Chicken Nuggets',
#   'restaurant': "Wendy's"},
#  {'calories': '220',
#   'carbs': '28',
#   'category': 'French Fries',
#   'fat': '11',
#   'name': 'Value French Fries',
#   'restaurant': "Wendy's"},
#  {'calories': '340',
#   'carbs': '28',
#   'category': 'Salads',
#   'fat': '18',
#   'name': 'Apple Pecan Chicken Salad Half-Size',
#   'restaurant': "Wendy's"},
#  {'calories': '480',
#   'carbs': '51',
#   'category': 'Sandwiches',
#   'fat': '23',
#   'name': 'Premium Cod Fillet Sandwich',
#   'restaurant': "Wendy's"},
#  {'calories': '390',
#   'carbs': '65',
#   'category': 'Shakes',
#   'fat': '10',
#   'name': 'Medium Vanilla Frosty™',
#   'restaurant': "Wendy's"},
#  {'calories': '990',
#   'carbs': '195',
#   'category': 'Shakes',
#   'fat': '18',
#   'name': 'Large Caramel Frosty™ Shake',
#   'restaurant': "Wendy's"},
#  {'calories': '580',
#   'carbs': '42',
#   'category': 'Burgers',
#   'fat': '31',
#   'name': "Dave's Hot 'N Juicy™ 1/4 lb.* Single",
#   'restaurant': "Wendy's"},
#  {'calories': '290',
#   'carbs': '26',
#   'category': 'Burgers',
#   'fat': '13',
#   'name': "Kids' Cheeseburger",
#   'restaurant': "Wendy's"},
#  {'calories': '270',
#   'carbs': '31',
#   'category': 'Entrees',
#   'fat': '8',
#   'name': 'Large Chili',
#   'restaurant': "Wendy's"},
#  {'calories': '580',
#   'carbs': '43',
#   'category': 'Salads',
#   'fat': '29',
#   'name': 'BBQ Ranch Chicken Salad',
#   'restaurant': "Wendy's"},
#  {'calories': '510',
#   'carbs': '54',
#   'category': 'Sandwiches',
#   'fat': '20',
#   'name': 'Homestyle Chicken Fillet',
#   'restaurant': "Wendy's"},
#  {'calories': '200',
#   'carbs': '32',
#   'category': 'Shakes',
#   'fat': '5',
#   'name': 'Jr. Original Chocolate Frosty™',
#   'restaurant': "Wendy's"},
#  {'calories': '410',
#   'carbs': '67',
#   'category': 'Shakes',
#   'fat': '10',
#   'name': 'Medium Original Chocolate Frosty™',
#   'restaurant': "Wendy's"},
#  {'calories': '820',
#   'carbs': '42',
#   'category': 'Burgers',
#   'fat': '47',
#   'name': "Dave's Hot 'N Juicy™ 1/2 lb.* Double",
#   'restaurant': "Wendy's"},
#  {'calories': '250',
#   'carbs': '25',
#   'category': 'Burgers',
#   'fat': '10',
#   'name': "Kids' Hamburger",
#   'restaurant': "Wendy's"},
#  {'calories': '220',
#   'carbs': '28',
#   'category': 'French Fries',
#   'fat': '11',
#   'name': 'Value French Fries',
#   'restaurant': "Wendy's"},
#  {'calories': '310',
#   'carbs': '25',
#   'category': 'Salads',
#   'fat': '14',
#   'name': 'BBQ Ranch Chicken Salad, Half Size',
#   'restaurant': "Wendy's"},
#  {'calories': '370',
#   'carbs': '43',
#   'category': 'Sandwiches',
#   'fat': '7',
#   'name': 'Ultimate Chicken Grill',
#   'restaurant': "Wendy's"},
#  {'calories': '590',
#   'carbs': '97',
#   'category': 'Shakes',
#   'fat': '15',
#   'name': 'Large Original Chocolate Frosty™',
#   'restaurant': "Wendy's"},
#  {'calories': '870',
#   'carbs': '164',
#   'category': 'Shakes',
#   'fat': '17',
#   'name': 'Large Chocolate Frosty™ Shake',
#   'restaurant': "Wendy's"},
#  {'calories': '1090',
#   'carbs': '43',
#   'category': 'Burgers',
#   'fat': '66',
#   'name': "Dave's Hot 'N Juicy™ 3/4 lb.* Triple",
#   'restaurant': "Wendy's"},
#  {'calories': '180',
#   'carbs': '10',
#   'category': 'Chicken',
#   'fat': '12',
#   'name': '4-piece Chicken Nuggets',
#   'restaurant': "Wendy's"},
#  {'calories': '220',
#   'carbs': '28',
#   'category': 'French Fries',
#   'fat': '11',
#   'name': "Kids' French Fries",
#   'restaurant': "Wendy's"},
#  {'calories': '570',
#   'carbs': '49',
#   'category': 'Salads',
#   'fat': '27',
#   'name': 'Apple Pecan Chicken Salad',
#   'restaurant': "Wendy's"},
#  {'calories': '350',
#   'carbs': '34',
#   'category': 'Sandwiches',
#   'fat': '19',
#   'name': 'Crispy Chicken Sandwich',
#   'restaurant': "Wendy's"},
#  {'calories': '280',
#   'carbs': '46',
#   'category': 'Shakes',
#   'fat': '7',
#   'name': 'Small Vanilla Frosty™',
#   'restaurant': "Wendy's"},
#  {'calories': '650',
#   'carbs': '121',
#   'category': 'Shakes',
#   'fat': '14',
#   'name': 'Small Caramel Frosty™ Shake',
#   'restaurant': "Wendy's"},
#  {'calories': '180',
#   'carbs': '20',
#   'category': 'Entrees',
#   'fat': '5',
#   'name': 'Small Chili',
#   'restaurant': "Wendy's"},
#  {'calories': '240',
#   'carbs': '20',
#   'category': 'Salads',
#   'fat': '10',
#   'name': 'Asian Cashew Chicken Salad, Half-Size',
#   'restaurant': "Wendy's"},
#  {'calories': '510',
#   'carbs': '55',
#   'category': 'Sandwiches',
#   'fat': '20',
#   'name': 'Spicy Chicken Sandwich',
#   'restaurant': "Wendy's"},
#  {'calories': '200',
#   'carbs': '32',
#   'category': 'Shakes',
#   'fat': '5',
#   'name': 'Jr. Original Chocolate Frosty™',
#   'restaurant': "Wendy's"},
#  {'calories': '260',
#   'carbs': '25',
#   'category': 'Wraps',
#   'fat': '10',
#   'name': 'Grilled Chicken Go Wrap',
#   'restaurant': "Wendy's"},
#  {'calories': '670',
#   'carbs': '57',
#   'category': 'Sandwiches',
#   'fat': '32',
#   'name': 'Asiago Ranch Chicken Club',
#   'restaurant': "Wendy's"},
#  {'calories': '330',
#   'carbs': '30',
#   'category': 'Wraps',
#   'fat': '16',
#   'name': 'Spicy Chicken Go Wrap',
#   'restaurant': "Wendy's"},
#  {'calories': '780',
#   'carbs': '149',
#   'category': 'Shakes',
#   'fat': '15',
#   'name': 'Large Strawberry Frosty™ Shake',
#   'restaurant': "Wendy's"}]

# %% [markdown]
# ### Step 4: Creating a pandas DataFrame from our list of foods

# %%
import pandas as pd

# %%
list_of_food_dicts = []
for i in range(len(results_list)):
    for x in range(len(results_list[i]['foods'])):
        dict = {}
        dict = (results_list[i]['foods'][x])
        list_of_food_dicts.append(dict)

# %%
df = pd.DataFrame(list_of_food_dicts)

# %%
df
# Out:
#      calories carbs      category fat                                name  \
# 0         760    45       Burgers  45  Original Bacon Double Cheeseburger
# 1         340    26       Entrees  20                   Coney (Chili) Dog
# 2         370    49  French Fries  15                         Chili Fries
# 3         670    90        Shakes  29        Strawberry Milkshake (small)
# 4         820   150        Shakes  18   A&amp;W® Root Beer Freeze (large)
# ...       ...   ...           ...  ..                                 ...
# 5126      200    32        Shakes   5      Jr. Original Chocolate Frosty™
# 5127      260    25         Wraps  10             Grilled Chicken Go Wrap
# 5128      670    57    Sandwiches  32           Asiago Ranch Chicken Club
# 5129      330    30         Wraps  16               Spicy Chicken Go Wrap
# 5130      780   149        Shakes  15      Large Strawberry Frosty™ Shake
#
#            restaurant
# 0     A&W Restaurants
# 1     A&W Restaurants
# 2     A&W Restaurants
# 3     A&W Restaurants
# 4     A&W Restaurants
# ...               ...
# 5126          Wendy's
# 5127          Wendy's
# 5128          Wendy's
# 5129          Wendy's
# 5130          Wendy's
#
# [5131 rows x 6 columns]

# %%
df = df[['name', 'calories', 'fat', 'carbs', 'restaurant']]

# %%
df
# Out:
#                                     name calories fat carbs       restaurant
# 0     Original Bacon Double Cheeseburger      760  45    45  A&W Restaurants
# 1                      Coney (Chili) Dog      340  20    26  A&W Restaurants
# 2                            Chili Fries      370  15    49  A&W Restaurants
# 3           Strawberry Milkshake (small)      670  29    90  A&W Restaurants
# 4      A&amp;W® Root Beer Freeze (large)      820  18   150  A&W Restaurants
# ...                                  ...      ...  ..   ...              ...
# 5126      Jr. Original Chocolate Frosty™      200   5    32          Wendy's
# 5127             Grilled Chicken Go Wrap      260  10    25          Wendy's
# 5128           Asiago Ranch Chicken Club      670  32    57          Wendy's
# 5129               Spicy Chicken Go Wrap      330  16    30          Wendy's
# 5130      Large Strawberry Frosty™ Shake      780  15   149          Wendy's
#
# [5131 rows x 5 columns]

# %% [markdown]
# ### Step 5: Exporting to csv

# %%
df.to_csv('nutrition_information.csv', index=False, sep=",")
